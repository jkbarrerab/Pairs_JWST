# %% [markdown]
# # COSMOSWeb Master Catalog Exploration
#
# This notebook explores the large COSMOSWeb master catalog FITS file to:
# - Understand the catalog structure and available columns
# - Apply initial filtering criteria efficiently
# - Create a manageable subset for detailed pair selection
# - Export filtered data for further analysis
#
# **Note**: This catalog is very large (~9GB), so we'll work with chunks and apply filters early to manage memory usage.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table
from astropy.cosmology import FlatLambdaCDM
from astropy import units as u
import gc
import warnings
warnings.filterwarnings('ignore')

# Define cosmology
cosmo = FlatLambdaCDM(H0=67.4, Om0=0.315)

# %% [markdown]
# ## 1. Initial FITS File Inspection

# %%
# First, let's inspect the FITS file structure without loading all data
fits_file = '../data/raw/COSMOSWeb_mastercatalog_v1.fits'

print("=== FITS File Information ===")
with fits.open(fits_file) as hdul:
    print(f"Number of HDUs: {len(hdul)}")
    hdul.info()
    
    print("\n=== Detailed HDU Information ===")
    for i, hdu in enumerate(hdul):
        print(f"\nHDU {i}: {hdu.name if hasattr(hdu, 'name') else 'Primary'}")
        print(f"  Type: {type(hdu).__name__}")
        
        if hasattr(hdu, 'header'):
            # Print relevant header info
            print(f"  Header keys: {len(hdu.header)} entries")
            if 'EXTNAME' in hdu.header:
                print(f"  Extension name: {hdu.header['EXTNAME']}")
            if 'TTYPE1' in hdu.header:
                print(f"  First column: {hdu.header['TTYPE1']}")
        
        # Check if it's a binary table with data
        if hasattr(hdu, 'columns') and hdu.columns is not None:
            print(f"  Columns: {len(hdu.columns)}")
            print(f"  Rows: {hdu.header.get('NAXIS2', 'Unknown')}")
            
            # Show first 10 column names
            col_names = [col.name for col in hdu.columns[:10]]
            print(f"  Sample columns: {', '.join(col_names)}")
            if len(hdu.columns) > 10:
                print(f"    ... and {len(hdu.columns) - 10} more")
                
        elif hasattr(hdu, 'data') and hdu.data is not None:
            print(f"  Data shape: {hdu.data.shape}")
            print(f"  Data type: {hdu.data.dtype}")
        else:
            print("  No data or header-only HDU")
# Out:
# === FITS File Information ===
# Number of HDUs: 7
# Filename: ../data/raw/COSMOSWeb_mastercatalog_v1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  PHOTOMETRY HOTCOLD AND SE++    1 BinTableHDU    603   784016R x 287C   [K, K, 3A, K, D, D, D, D, D, D, D, D, D, 4A, D, D, D, D, D, 5D, 5D, 5D, D, D, D, D, D, 5D, 5D, 5D, D, D, D, D, D, 5D, 5D, 5D, D, D, D, D, D, 5D, 5D, 5D, D, D, D, D, D, 5D, 5D, 5D, D, D, D, D, D, 5D, 5D, 5D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, L, L, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, K, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, I, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, K]
#   2  LEPHARE       1 BinTableHDU     97   784016R x 43C   [D, K, D, D, D, D, D, K, D, D, D, D, D, K, D, K, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D]
#   3  SE++APER      1 BinTableHDU    454   784016R x 148C   [5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E]
#   4  CIGALE        1 BinTableHDU    118   784016R x 54C   [D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D]
#   5  ML-MORPHO     1 BinTableHDU    314   784016R x 150C   [D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, K, D, K, D, K, D]
#   6  B+D           1 BinTableHDU    932   784016R x 461C   [D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D]
#
# === Detailed HDU Information ===
#
# HDU 0: PRIMARY
#   Type: PrimaryHDU
#   Header keys: 4 entries
#   No data or header-only HDU
#
# HDU 1: PHOTOMETRY HOTCOLD AND SE++
#   Type: BinTableHDU
#   Header keys: 603 entries
#   Extension name: PHOTOMETRY HOTCOLD AND SE++
#   First column: id
#   Columns: 287
#   Rows: 784016
#   Sample columns: id, segment-id, tile, id_specz_khostovan25, ra, dec, x_image, y_image, a_image, b_image
#     ... and 277 more
#
# HDU 2: LEPHARE
#   Type: BinTableHDU
#   Header keys: 97 entries
#   Extension name: LEPHARE
#   First column: zfinal
#   Columns: 43
#   Rows: 784016
#   Sample columns: zfinal, type, zpdf_med, zpdf_l68, zpdf_u68, zchi2, chi2_best, nbfilt, zp_agn, chi2_agn
#     ... and 33 more
#
# HDU 3: SE++APER
#   Type: BinTableHDU
#   Header keys: 454 entries
#   Extension name: SE++APER
#   First column: mag_aper_f115w
#   Columns: 148
#   Rows: 784016
#   Sample columns: mag_aper_f115w, mag_aper_f150w, mag_aper_f277w, mag_aper_f444w, mag_aper_hst-f814w, mag_aper_f770w, mag_aper_cfht-u, mag_aper_hsc-g, mag_aper_hsc-r, mag_aper_hsc-i
#     ... and 138 more
#
# HDU 4: CIGALE
#   Type: BinTableHDU
#   Header keys: 118 entries
#   Extension name: CIGALE
#   First column: age_form
#   Columns: 54
#   Rows: 784016
#   Sample columns: age_form, age_form_err, sfr_mass_vector_dir, sfr_mass_vector_dir_err, sfh_sfr_bin1, sfh_sfr_bin1_err, sfh_sfr_bin2, sfh_sfr_bin2_err, sfh_sfr_bin3, sfh_sfr_bin3_err
#     ... and 44 more
#
# HDU 5: ML-MORPHO
#   Type: BinTableHDU
#   Header keys: 314 entries
#   Extension name: ML-MORPHO
#   First column: sph_0_f150w
#   Columns: 150
#   Rows: 784016
#   Sample columns: sph_0_f150w, disk_0_f150w, irr_0_f150w, bd_0_f150w, sph_1_f150w, disk_1_f150w, irr_1_f150w, bd_1_f150w, sph_2_f150w, disk_2_f150w
#     ... and 140 more
#
# HDU 6: B+D
#   Type: BinTableHDU
#   Header keys: 932 entries
#   Extension name: B+D
#   First column: ra_detec_bd
#   Columns: 461
#   Rows: 784016
#   Sample columns: ra_detec_bd, dec_detec_bd, disk_radius_deg, disk_radius_deg_err, bulge_radius_deg, bulge_radius_deg_err, angle_bd, angle_bd_err, disk_axratio, disk_axratio_err
#     ... and 451 more

# %%
# Explore all HDUs and identify which ones contain data
print("=== Exploring All HDUs for Data ===")

data_hdus = []
with fits.open(fits_file) as hdul:
    for i, hdu in enumerate(hdul):
        if hasattr(hdu, 'columns') and hdu.columns is not None and len(hdu.columns) > 0:
            n_rows = hdu.header.get('NAXIS2', 0)
            n_cols = len(hdu.columns)
            ext_name = hdu.header.get('EXTNAME', f'HDU_{i}')
            
            data_hdus.append({
                'hdu_index': i,
                'ext_name': ext_name,
                'n_rows': n_rows,
                'n_cols': n_cols,
                'columns': [col.name for col in hdu.columns]
            })
            
            print(f"HDU {i} ({ext_name}): {n_rows:,} rows × {n_cols} columns")
            # Show first 10 column names
            col_sample = [col.name for col in hdu.columns[:10]]
            print(f"  Sample columns: {', '.join(col_sample)}")
            if len(hdu.columns) > 10:
                print(f"  ... and {len(hdu.columns) - 10} more")

print(f"\nFound {len(data_hdus)} HDUs with data tables")

# Look for common ID/matching columns across HDUs
if len(data_hdus) > 1:
    print("\n=== Checking for Common ID Columns Across HDUs ===")
    
    # Common ID column patterns
    id_patterns = ['id', 'ID', 'object', 'source', 'number', 'index']
    
    for hdu_info in data_hdus:
        print(f"HDU {hdu_info['hdu_index']} ({hdu_info['ext_name']}):")
        id_cols = []
        for pattern in id_patterns:
            id_cols.extend([col for col in hdu_info['columns'] if pattern.lower() in col.lower()])
        
        if id_cols:
            print(f"  Potential ID columns: {', '.join(set(id_cols))}")
        else:
            print("  No obvious ID columns found")
            # Show first few columns as potential IDs
            print(f"  First columns (potential IDs): {', '.join(hdu_info['columns'][:3])}")
else:
    print("Only one data HDU found - no merging needed")
# Out:
# === Exploring All HDUs for Data ===
# HDU 1 (PHOTOMETRY HOTCOLD AND SE++): 784,016 rows × 287 columns
#   Sample columns: id, segment-id, tile, id_specz_khostovan25, ra, dec, x_image, y_image, a_image, b_image
#   ... and 277 more
# HDU 2 (LEPHARE): 784,016 rows × 43 columns
#   Sample columns: zfinal, type, zpdf_med, zpdf_l68, zpdf_u68, zchi2, chi2_best, nbfilt, zp_agn, chi2_agn
#   ... and 33 more
# HDU 3 (SE++APER): 784,016 rows × 148 columns
#   Sample columns: mag_aper_f115w, mag_aper_f150w, mag_aper_f277w, mag_aper_f444w, mag_aper_hst-f814w, mag_aper_f770w, mag_aper_cfht-u, mag_aper_hsc-g, mag_aper_hsc-r, mag_aper_hsc-i
#   ... and 138 more
# HDU 4 (CIGALE): 784,016 rows × 54 columns
#   Sample columns: age_form, age_form_err, sfr_mass_vector_dir, sfr_mass_vector_dir_err, sfh_sfr_bin1, sfh_sfr_bin1_err, sfh_sfr_bin2, sfh_sfr_bin2_err, sfh_sfr_bin3, sfh_sfr_bin3_err
#   ... and 44 more
# HDU 5 (ML-MORPHO): 784,016 rows × 150 columns
#   Sample columns: sph_0_f150w, disk_0_f150w, irr_0_f150w, bd_0_f150w, sph_1_f150w, disk_1_f150w, irr_1_f150w, bd_1_f150w, sph_2_f150w, disk_2_f150w
#   ... and 140 more
# HDU 6 (B+D): 784,016 rows × 461 columns
#   Sample columns: ra_detec_bd, dec_detec_bd, disk_radius_deg, disk_radius_deg_err, bulge_radius_deg, bulge_radius_deg_err, angle_bd, angle_bd_err, disk_axratio, disk_axratio_err
#   ... and 451 more
#
# Found 6 HDUs with data tables
#
# === Checking for Common ID Columns Across HDUs ===
# HDU 1 (PHOTOMETRY HOTCOLD AND SE++):
#   Potential ID columns: id_specz_khostovan25, group_id, id, segment-id
# HDU 2 (LEPHARE):
#   No obvious ID columns found
#   First columns (potential IDs): zfinal, type, zpdf_med
# HDU 3 (SE++APER):
#   No obvious ID columns found
#   First columns (potential IDs): mag_aper_f115w, mag_aper_f150w, mag_aper_f277w
# HDU 4 (CIGALE):
#   No obvious ID columns found
#   First columns (potential IDs): age_form, age_form_err, sfr_mass_vector_dir
# HDU 5 (ML-MORPHO):
#   No obvious ID columns found
#   First columns (potential IDs): sph_0_f150w, disk_0_f150w, irr_0_f150w
# HDU 6 (B+D):
#   No obvious ID columns found
#   First columns (potential IDs): ra_detec_bd, dec_detec_bd, disk_radius_deg

# %%
# Load and combine data from all HDUs
print("=== Loading Data from All HDUs ===")

# Define the ID column to use for merging (UPDATE AFTER RUNNING PREVIOUS CELL)
MERGE_COLUMN = None  # e.g., 'id', 'ID', 'object_id', etc.

print("MANUAL UPDATE REQUIRED:")
print("After seeing the HDU analysis above, update MERGE_COLUMN with the common ID column name")
print("Example: MERGE_COLUMN = 'id'  # or 'ID', 'object_id', etc.")
print("If HDUs have different ID column names, you may need to rename them during loading\n")

def load_all_hdus(filename, merge_col=None):
    """
    Load data from all HDUs and optionally merge them
    """
    tables = {}
    
    with fits.open(filename) as hdul:
        print(f"Loading data from {len(data_hdus)} HDUs...")
        
        for hdu_info in data_hdus:
            hdu_idx = hdu_info['hdu_index']
            ext_name = hdu_info['ext_name']
            
            print(f"Loading HDU {hdu_idx} ({ext_name})...")
            try:
                # Load the HDU data
                table = Table(hdul[hdu_idx].data)
                tables[ext_name] = table
                print(f"  ✓ Loaded {len(table)} rows × {len(table.colnames)} columns")
                
            except Exception as e:
                print(f"  ✗ Error loading HDU {hdu_idx}: {e}")
                continue
    
    if len(tables) == 1:
        # Only one table, return it directly
        table_name = list(tables.keys())[0]
        print(f"\nReturning single table: {table_name}")
        return tables[table_name], {}
        
    elif len(tables) > 1 and merge_col is not None:
        # Multiple tables, try to merge them
        print(f"\n=== Merging {len(tables)} tables on column '{merge_col}' ===")
        
        table_names = list(tables.keys())
        merged_table = tables[table_names[0]]
        merge_info = {table_names[0]: len(merged_table)}
        
        print(f"Starting with {table_names[0]}: {len(merged_table)} rows")
        
        for table_name in table_names[1:]:
            table_to_merge = tables[table_name]
            
            # Check if merge column exists in both tables
            if merge_col in merged_table.colnames and merge_col in table_to_merge.colnames:
                print(f"Merging {table_name}: {len(table_to_merge)} rows")
                
                # Convert to pandas for easier merging
                df1 = merged_table.to_pandas()
                df2 = table_to_merge.to_pandas()
                
                # Merge on the common ID column
                merged_df = pd.merge(df1, df2, on=merge_col, how='inner', suffixes=('', f'_{table_name}'))
                
                # Convert back to astropy Table
                merged_table = Table.from_pandas(merged_df)
                merge_info[table_name] = len(table_to_merge)
                
                print(f"  After merge: {len(merged_table)} rows")
                
            else:
                print(f"  ✗ Cannot merge {table_name}: missing column '{merge_col}'")
                if merge_col not in table_to_merge.colnames:
                    print(f"    Available columns: {', '.join(table_to_merge.colnames[:10])}...")
        
        print(f"\nFinal merged table: {len(merged_table)} rows × {len(merged_table.colnames)} columns")
        return merged_table, merge_info
        
    else:
        # Multiple tables but no merge column specified
        print(f"\n=== Returning {len(tables)} separate tables ===")
        print("No merge column specified. Consider setting MERGE_COLUMN to combine tables.")
        return tables, {}

# Load the data
if MERGE_COLUMN is not None:
    catalog, merge_info = load_all_hdus(fits_file, MERGE_COLUMN)
    if isinstance(catalog, dict):
        print("Multiple tables loaded separately:")
        for name, table in catalog.items():
            print(f"  {name}: {len(table)} rows × {len(table.colnames)} columns")
        # For now, use the first table for analysis
        catalog = list(catalog.values())[0]
        print(f"Using first table for analysis: {len(catalog)} rows")
else:
    print("Please set MERGE_COLUMN first!")

# %%
# Alternative: Load all HDUs without merging (safer approach)
print("=== Alternative: Loading All HDUs Separately ===")

def load_all_hdus_separate(filename):
    """
    Load all HDUs as separate tables for inspection
    """
    all_tables = {}
    
    with fits.open(filename) as hdul:
        print(f"Loading all {len(data_hdus)} data HDUs...")
        
        for hdu_info in data_hdus:
            hdu_idx = hdu_info['hdu_index']
            ext_name = hdu_info['ext_name']
            
            try:
                print(f"Loading HDU {hdu_idx} ({ext_name})...")
                table = Table(hdul[hdu_idx].data)
                all_tables[ext_name] = table
                print(f"  ✓ {len(table):,} rows × {len(table.colnames)} columns")
                
                # Memory usage estimate
                memory_mb = len(table) * len(table.colnames) * 8 / 1e6
                print(f"  Memory: ~{memory_mb:.1f} MB")
                
            except Exception as e:
                print(f"  ✗ Error: {e}")
    
    return all_tables

# Load all tables
all_catalogs = load_all_hdus_separate(fits_file)

print(f"\n=== Loaded {len(all_catalogs)} catalogs ===")
total_memory = 0
for name, table in all_catalogs.items():
    memory_mb = len(table) * len(table.colnames) * 8 / 1e6
    total_memory += memory_mb
    print(f"{name}: {len(table):,} objects, {len(table.colnames)} columns")

print(f"\nTotal estimated memory: ~{total_memory:.1f} MB")

# Choose primary catalog for analysis
if len(all_catalogs) > 0:
    # Use the largest table as primary, or specify manually
    primary_name = max(all_catalogs.keys(), key=lambda k: len(all_catalogs[k]))
    catalog = all_catalogs[primary_name]
    print(f"\nUsing '{primary_name}' as primary catalog ({len(catalog):,} objects)")
    
    # Store others for later use if needed
    secondary_catalogs = {k: v for k, v in all_catalogs.items() if k != primary_name}
    if secondary_catalogs:
        print(f"Secondary catalogs available: {', '.join(secondary_catalogs.keys())}")
else:
    print("No catalogs loaded successfully!")
# Out:
# === Alternative: Loading All HDUs Separately ===
# Loading all 6 data HDUs...
# Loading HDU 1 (PHOTOMETRY HOTCOLD AND SE++)...
#   ✓ 784,016 rows × 287 columns
#   Memory: ~1800.1 MB
# Loading HDU 2 (LEPHARE)...
#   ✓ 784,016 rows × 43 columns
#   Memory: ~269.7 MB
# Loading HDU 3 (SE++APER)...
#   ✓ 784,016 rows × 148 columns
#   Memory: ~928.3 MB
# Loading HDU 4 (CIGALE)...
#   ✓ 784,016 rows × 54 columns
#   Memory: ~338.7 MB
# Loading HDU 5 (ML-MORPHO)...
#   ✓ 784,016 rows × 150 columns
#   Memory: ~940.8 MB
# Loading HDU 6 (B+D)...
#   ✓ 784,016 rows × 461 columns
#   Memory: ~2891.5 MB
#
# === Loaded 6 catalogs ===
# PHOTOMETRY HOTCOLD AND SE++: 784,016 objects, 287 columns
# LEPHARE: 784,016 objects, 43 columns
# SE++APER: 784,016 objects, 148 columns
# CIGALE: 784,016 objects, 54 columns
# ML-MORPHO: 784,016 objects, 150 columns
# B+D: 784,016 objects, 461 columns
#
# Total estimated memory: ~7169.0 MB
#
# Using 'PHOTOMETRY HOTCOLD AND SE++' as primary catalog (784,016 objects)
# Secondary catalogs available: LEPHARE, SE++APER, CIGALE, ML-MORPHO, B+D

# %%
# Concatenate all catalogs horizontally (side by side)
print("=== CONCATENATING ALL CATALOGS HORIZONTALLY ===")

def concatenate_all_catalogs(all_cats):
    """
    Concatenate all catalogs horizontally, assuming rows are in the same order
    """
    if not all_cats:
        print("No catalogs to concatenate!")
        return None
    
    print(f"Concatenating {len(all_cats)} catalogs...")
    
    # Check that all catalogs have the same number of rows
    row_counts = {name: len(table) for name, table in all_cats.items()}
    print("Row counts per catalog:")
    for name, count in row_counts.items():
        print(f"  {name}: {count:,} rows")
    
    # Check if all have the same number of rows
    unique_counts = set(row_counts.values())
    if len(unique_counts) > 1:
        print(f"⚠ WARNING: Catalogs have different numbers of rows: {unique_counts}")
        print("Using the smallest common size...")
        min_rows = min(row_counts.values())
        print(f"Will use first {min_rows:,} rows from each catalog")
    else:
        min_rows = list(unique_counts)[0]
        print(f"✓ All catalogs have {min_rows:,} rows")
    
    # Start with the first catalog
    cat_names = list(all_cats.keys())
    combined_table = all_cats[cat_names[0]][:min_rows].copy()
    
    print(f"Starting with {cat_names[0]}: {len(combined_table.colnames)} columns")
    
    # Add columns from other catalogs
    for cat_name in cat_names[1:]:
        source_table = all_cats[cat_name][:min_rows]
        
        print(f"Adding {cat_name}: {len(source_table.colnames)} columns")
        
        # Check for column name conflicts
        conflicts = set(combined_table.colnames) & set(source_table.colnames)
        if conflicts:
            print(f"  Column conflicts: {', '.join(list(conflicts)[:5])}...")
            # Rename conflicting columns with suffix
            for col in source_table.colnames:
                if col in combined_table.colnames:
                    new_col_name = f"{col}_{cat_name}"
                    source_table.rename_column(col, new_col_name)
                    print(f"    Renamed {col} → {new_col_name}")
        
        # Add all columns from this catalog
        for col_name in source_table.colnames:
            combined_table[col_name] = source_table[col_name]
    
    print(f"\n✓ Combined catalog created:")
    print(f"  Rows: {len(combined_table):,}")
    print(f"  Columns: {len(combined_table.colnames)}")
    print(f"  Estimated memory: ~{len(combined_table) * len(combined_table.colnames) * 8 / 1e6:.1f} MB")
    
    return combined_table

# Concatenate all catalogs
if 'all_catalogs' in locals() and all_catalogs:
    unified_catalog = concatenate_all_catalogs(all_catalogs)
    
    if unified_catalog is not None:
        print(f"\n=== SUCCESS ===")
        print(f"Unified catalog: {len(unified_catalog):,} objects × {len(unified_catalog.colnames)} columns")
        
        # Set this as the main catalog for analysis
        catalog = unified_catalog
        print("✓ Set as main 'catalog' variable for further analysis")
    else:
        print("Failed to create unified catalog")
else:
    print("ERROR: all_catalogs not found. Please run the previous cells first.")
# Out:
# === CONCATENATING ALL CATALOGS HORIZONTALLY ===
# Concatenating 6 catalogs...
# Row counts per catalog:
#   PHOTOMETRY HOTCOLD AND SE++: 784,016 rows
#   LEPHARE: 784,016 rows
#   SE++APER: 784,016 rows
#   CIGALE: 784,016 rows
#   ML-MORPHO: 784,016 rows
#   B+D: 784,016 rows
# ✓ All catalogs have 784,016 rows
# Starting with PHOTOMETRY HOTCOLD AND SE++: 287 columns
# Adding LEPHARE: 43 columns
# Adding SE++APER: 148 columns
#   Column conflicts: flux_err_aper_f150w, mag_aper_f770w, flux_aper_hst-f814w, mag_aper_f115w, flux_err_aper_f277w...
#     Renamed mag_aper_f115w → mag_aper_f115w_SE++APER
#     Renamed mag_aper_f150w → mag_aper_f150w_SE++APER
#     Renamed mag_aper_f277w → mag_aper_f277w_SE++APER
#     Renamed mag_aper_f444w → mag_aper_f444w_SE++APER
#     Renamed mag_aper_hst-f814w → mag_aper_hst-f814w_SE++APER
#     Renamed mag_aper_f770w → mag_aper_f770w_SE++APER
#     Renamed flux_aper_f115w → flux_aper_f115w_SE++APER
#     Renamed flux_aper_f150w → flux_aper_f150w_SE++APER
#     Renamed flux_aper_f277w → flux_aper_f277w_SE++APER
#     Renamed flux_aper_f444w → flux_aper_f444w_SE++APER
#     Renamed flux_aper_hst-f814w → flux_aper_hst-f814w_SE++APER
#     Renamed flux_aper_f770w → flux_aper_f770w_SE++APER
#     Renamed flux_err_aper_f115w → flux_err_aper_f115w_SE++APER
#     Renamed flux_err_aper_f150w → flux_err_aper_f150w_SE++APER
#     Renamed flux_err_aper_f277w → flux_err_aper_f277w_SE++APER
#     Renamed flux_err_aper_f444w → flux_err_aper_f444w_SE++APER
#     Renamed flux_err_aper_hst-f814w → flux_err_aper_hst-f814w_SE++APER
#     Renamed flux_err_aper_f770w → flux_err_aper_f770w_SE++APER
# Adding CIGALE: 54 columns
# Adding ML-MORPHO: 150 columns
# Adding B+D: 461 columns
#
# ✓ Combined catalog created:
#   Rows: 784,016
#   Columns: 1143
#   Estimated memory: ~7169.0 MB
#
# === SUCCESS ===
# Unified catalog: 784,016 objects × 1143 columns
# ✓ Set as main 'catalog' variable for further analysis

# %%
# Comprehensive column analysis across all loaded catalogs
print("=== COMPREHENSIVE COLUMN ANALYSIS ===")

if 'all_catalogs' in locals() and all_catalogs:
    all_columns = {}
    
    # Collect all column names from all catalogs
    for cat_name, table in all_catalogs.items():
        all_columns[cat_name] = table.colnames
        print(f"\n{cat_name}: {len(table.colnames)} columns")
        
        # Print columns in organized format
        cols_per_row = 4
        for i in range(0, len(table.colnames), cols_per_row):
            row_cols = table.colnames[i:i+cols_per_row]
            formatted_cols = [f"{j+i+1:3d}. {col:<20}" for j, col in enumerate(row_cols)]
            print("    " + " ".join(formatted_cols))
    
    # Create comprehensive column search across ALL catalogs
    print("\n" + "="*100)
    print("=== SEARCHING ALL CATALOGS FOR KEY COLUMNS ===")
    
    key_patterns = {
        'id': ['id', 'ID', 'object', 'source', 'number', 'index'],
        'coordinates': ['RA', 'DEC', 'ra', 'dec', 'ALPHA', 'DELTA', 'alpha', 'delta', 'coord'],
        'redshift': ['z', 'Z', 'redshift', 'REDSHIFT', 'z_phot', 'z_spec', 'zphot', 'zspec', 'zbest'],
        'stellar_mass': ['mass', 'MASS', 'lmass', 'stellar', 'logm', 'mstar', 'M_star'],
        'sfr': ['sfr', 'SFR', 'star_formation', 'formation_rate', 'psi'],
        'size': ['re', 'RE', 'r_eff', 'radius', 'size', 'kron', 'petro', 'half_light'],
        'magnitude': ['mag', 'MAG', 'flux', 'FLUX', 'f606w', 'f814w', 'f160w', 'AB'],
        'colors': ['color', 'COLOR', 'g_r', 'r_i', 'i_z'],
        'morphology': ['morph', 'class', 'type', 'flag', 'stellar', 'galaxy', 'sersic'],
        'photometry': ['f435w', 'f606w', 'f814w', 'f125w', 'f140w', 'f160w', 'ks', 'irac', 'wise'],
        'environment': ['density', 'neighbor', 'isolation', 'group'],
        'quality': ['flag', 'qual', 'error', 'chi', 'prob']
    }
    
    # Search for patterns across all catalogs
    global_found_cols = {}
    for category, patterns in key_patterns.items():
        category_matches = {}
        
        for cat_name, columns in all_columns.items():
            matches = []
            for pattern in patterns:
                matches.extend([col for col in columns if pattern.lower() in col.lower()])
            
            if matches:
                category_matches[cat_name] = list(set(matches))
        
        if category_matches:
            global_found_cols[category] = category_matches
            
            print(f"\n{category.upper()}:")
            for cat_name, cols in category_matches.items():
                print(f"  {cat_name}: {', '.join(cols[:5])}")
                if len(cols) > 5:
                    print(f"    ... and {len(cols) - 5} more")
    
    # Create unified column mapping suggestions
    print("\n" + "="*100)
    print("=== SUGGESTED COLUMN MAPPING ===")
    
    suggested_mapping = {}
    for category, cat_matches in global_found_cols.items():
        if cat_matches:
            # Find the catalog with the most matches for this category
            best_cat = max(cat_matches.keys(), key=lambda k: len(cat_matches[k]))
            best_cols = cat_matches[best_cat]
            
            # Suggest the first/best column
            suggested_mapping[category] = {
                'catalog': best_cat,
                'column': best_cols[0],
                'alternatives': best_cols[1:5] if len(best_cols) > 1 else []
            }
    
    print("Recommended columns for analysis:")
    print("column_mapping = {")
    for category, info in suggested_mapping.items():
        alternatives_str = f" # alternatives: {', '.join(info['alternatives'])}" if info['alternatives'] else ""
        print(f"    '{category}': ('{info['catalog']}', '{info['column']}'),{alternatives_str}")
    print("}")
    
else:
    print("No catalogs loaded. Please run the previous cells first.")
# Out:
# === COMPREHENSIVE COLUMN ANALYSIS ===
#
# PHOTOMETRY HOTCOLD AND SE++: 287 columns
#       1. id                     2. segment-id             3. tile                   4. id_specz_khostovan25
#       5. ra                     6. dec                    7. x_image                8. y_image
#       9. a_image               10. b_image               11. theta_image           12. theta_world
#      13. chi2_max              14. mode                  15. snr_hst-f814w         16. wht_hst-f814w
#      17. flux_auto_hst-f814w   18. flux_err_auto_hst-f814w  19. mag_auto_hst-f814w    20. flux_aper_hst-f814w
#      21. flux_err_aper_hst-f814w  22. mag_aper_hst-f814w    23. snr_f115w             24. wht_f115w
#      25. flux_auto_f115w       26. flux_err_auto_f115w   27. mag_auto_f115w        28. flux_aper_f115w
#      29. flux_err_aper_f115w   30. mag_aper_f115w        31. snr_f150w             32. wht_f150w
#      33. flux_auto_f150w       34. flux_err_auto_f150w   35. mag_auto_f150w        36. flux_aper_f150w
#      37. flux_err_aper_f150w   38. mag_aper_f150w        39. snr_f277w             40. wht_f277w
#      41. flux_auto_f277w       42. flux_err_auto_f277w   43. mag_auto_f277w        44. flux_aper_f277w
#      45. flux_err_aper_f277w   46. mag_aper_f277w        47. snr_f444w             48. wht_f444w
#      49. flux_auto_f444w       50. flux_err_auto_f444w   51. mag_auto_f444w        52. flux_aper_f444w
#      53. flux_err_aper_f444w   54. mag_aper_f444w        55. snr_f770w             56. wht_f770w
#      57. flux_auto_f770w       58. flux_err_auto_f770w   59. mag_auto_f770w        60. flux_aper_f770w
#      61. flux_err_aper_f770w   62. mag_aper_f770w        63. c_f444w               64. fwhm
#      65. mu_max_hst-f814w      66. mu_max_f115w          67. mu_max_f150w          68. mu_max_f277w
#      69. mu_max_f444w          70. mu_max_f770w          71. kron_rad              72. kron1_a
#      73. kron1_b               74. kron1_area            75. kron2_a               76. kron2_b
#      77. kron2_area            78. seg_area              79. kron_corr             80. kron_f444w_psf_corr
#      81. kron_f770w_psf_corr   82. kron_f770w_ap_corr    83. flag_star             84. flag_blend
#      85. ra_model              86. dec_model             87. radius_sersic         88. radius_sersic_err
#      89. axratio_sersic        90. axratio_sersic_err    91. sersic                92. sersic_err
#      93. angle_sersic          94. angle_sersic_err      95. e1                    96. e1_err
#      97. e2                    98. e2_err                99. fmf_chi2             100. group_id
#     101. mag_model_f115w      102. mag_model_f150w      103. mag_model_f277w      104. mag_model_f444w
#     105. mag_model_hst-f814w  106. mag_model_f770w      107. mag_model_cfht-u     108. mag_model_hsc-g
#     109. mag_model_hsc-r      110. mag_model_hsc-i      111. mag_model_hsc-z      112. mag_model_hsc-y
#     113. mag_model_hsc-nb0816 114. mag_model_hsc-nb0921 115. mag_model_hsc-nb1010 116. mag_model_uvista-y
#     117. mag_model_uvista-j   118. mag_model_uvista-h   119. mag_model_uvista-ks  120. mag_model_uvista-nb118
#     121. mag_model_sc-ia484   122. mag_model_sc-ia527   123. mag_model_sc-ia624   124. mag_model_sc-ia679
#     125. mag_model_sc-ia738   126. mag_model_sc-ia767   127. mag_model_sc-ib427   128. mag_model_sc-ib505
#     129. mag_model_sc-ib574   130. mag_model_sc-ib709   131. mag_model_sc-ib827   132. mag_model_sc-nb711
#     133. mag_model_sc-nb816   134. mag_model_irac-ch1   135. mag_model_irac-ch2   136. mag_model_irac-ch3
#     137. mag_model_irac-ch4   138. mag_err_model_f115w  139. mag_err_model_f150w  140. mag_err_model_f277w
#     141. mag_err_model_f444w  142. mag_err_model_hst-f814w 143. mag_err_model_f770w  144. mag_err_model_cfht-u
#     145. mag_err_model_hsc-g  146. mag_err_model_hsc-r  147. mag_err_model_hsc-i  148. mag_err_model_hsc-z
#     149. mag_err_model_hsc-y  150. mag_err_model_hsc-nb0816 151. mag_err_model_hsc-nb0921 152. mag_err_model_hsc-nb1010
#     153. mag_err_model_uvista-y 154. mag_err_model_uvista-j 155. mag_err_model_uvista-h 156. mag_err_model_uvista-ks
#     157. mag_err_model_uvista-nb118 158. mag_err_model_sc-ia484 159. mag_err_model_sc-ia527 160. mag_err_model_sc-ia624
#     161. mag_err_model_sc-ia679 162. mag_err_model_sc-ia738 163. mag_err_model_sc-ia767 164. mag_err_model_sc-ib427
#     165. mag_err_model_sc-ib505 166. mag_err_model_sc-ib574 167. mag_err_model_sc-ib709 168. mag_err_model_sc-ib827
#     169. mag_err_model_sc-nb711 170. mag_err_model_sc-nb816 171. mag_err_model_irac-ch1 172. mag_err_model_irac-ch2
#     173. mag_err_model_irac-ch3 174. mag_err_model_irac-ch4 175. flux_model_f115w     176. flux_model_f150w
#     177. flux_model_f277w     178. flux_model_f444w     179. flux_model_hst-f814w 180. flux_model_f770w
#     181. flux_model_cfht-u    182. flux_model_hsc-g     183. flux_model_hsc-r     184. flux_model_hsc-i
#     185. flux_model_hsc-z     186. flux_model_hsc-y     187. flux_model_hsc-nb0816 188. flux_model_hsc-nb0921
#     189. flux_model_hsc-nb1010 190. flux_model_uvista-y  191. flux_model_uvista-j  192. flux_model_uvista-h
#     193. flux_model_uvista-ks 194. flux_model_uvista-nb118 195. flux_model_sc-ia484  196. flux_model_sc-ia527
#     197. flux_model_sc-ia624  198. flux_model_sc-ia679  199. flux_model_sc-ia738  200. flux_model_sc-ia767
#     201. flux_model_sc-ib427  202. flux_model_sc-ib505  203. flux_model_sc-ib574  204. flux_model_sc-ib709
#     205. flux_model_sc-ib827  206. flux_model_sc-nb711  207. flux_model_sc-nb816  208. flux_model_irac-ch1
#     209. flux_model_irac-ch2  210. flux_model_irac-ch3  211. flux_model_irac-ch4  212. flux_err-uncal_model_f115w
#     213. flux_err-uncal_model_f150w 214. flux_err-uncal_model_f277w 215. flux_err-uncal_model_f444w 216. flux_err-uncal_model_hst-f814w
#     217. flux_err-uncal_model_f770w 218. flux_err-uncal_model_cfht-u 219. flux_err-uncal_model_hsc-g 220. flux_err-uncal_model_hsc-r
#     221. flux_err-uncal_model_hsc-i 222. flux_err-uncal_model_hsc-z 223. flux_err-uncal_model_hsc-y 224. flux_err-uncal_model_hsc-nb0816
#     225. flux_err-uncal_model_hsc-nb0921 226. flux_err-uncal_model_hsc-nb1010 227. flux_err-uncal_model_uvista-y 228. flux_err-uncal_model_uvista-j
#     229. flux_err-uncal_model_uvista-h 230. flux_err-uncal_model_uvista-ks 231. flux_err-uncal_model_uvista-nb118 232. flux_err-uncal_model_sc-ia484
#     233. flux_err-uncal_model_sc-ia527 234. flux_err-uncal_model_sc-ia624 235. flux_err-uncal_model_sc-ia679 236. flux_err-uncal_model_sc-ia738
#     237. flux_err-uncal_model_sc-ia767 238. flux_err-uncal_model_sc-ib427 239. flux_err-uncal_model_sc-ib505 240. flux_err-uncal_model_sc-ib574
#     241. flux_err-uncal_model_sc-ib709 242. flux_err-uncal_model_sc-ib827 243. flux_err-uncal_model_sc-nb711 244. flux_err-uncal_model_sc-nb816
#     245. flux_err-uncal_model_irac-ch1 246. flux_err-uncal_model_irac-ch2 247. flux_err-uncal_model_irac-ch3 248. flux_err-uncal_model_irac-ch4
#     249. flag_star_hsc        250. flux_err-cal_model_f115w 251. flux_err-cal_model_f150w 252. flux_err-cal_model_f277w
#     253. flux_err-cal_model_f444w 254. flux_err-cal_model_hst-f814w 255. flux_err-cal_model_f770w 256. flux_err-cal_model_cfht-u
#     257. flux_err-cal_model_hsc-g 258. flux_err-cal_model_hsc-r 259. flux_err-cal_model_hsc-i 260. flux_err-cal_model_hsc-z
#     261. flux_err-cal_model_hsc-y 262. flux_err-cal_model_hsc-nb0816 263. flux_err-cal_model_hsc-nb0921 264. flux_err-cal_model_hsc-nb1010
#     265. flux_err-cal_model_uvista-y 266. flux_err-cal_model_uvista-j 267. flux_err-cal_model_uvista-h 268. flux_err-cal_model_uvista-ks
#     269. flux_err-cal_model_uvista-nb118 270. flux_err-cal_model_sc-ia484 271. flux_err-cal_model_sc-ia527 272. flux_err-cal_model_sc-ia624
#     273. flux_err-cal_model_sc-ia679 274. flux_err-cal_model_sc-ia738 275. flux_err-cal_model_sc-ia767 276. flux_err-cal_model_sc-ib427
#     277. flux_err-cal_model_sc-ib505 278. flux_err-cal_model_sc-ib574 279. flux_err-cal_model_sc-ib709 280. flux_err-cal_model_sc-ib827
#     281. flux_err-cal_model_sc-nb711 282. flux_err-cal_model_sc-nb816 283. flux_err-cal_model_irac-ch1 284. flux_err-cal_model_irac-ch2
#     285. flux_err-cal_model_irac-ch3 286. flux_err-cal_model_irac-ch4 287. warn_flag
#
# LEPHARE: 43 columns
#       1. zfinal                 2. type                   3. zpdf_med               4. zpdf_l68
#       5. zpdf_u68               6. zchi2                  7. chi2_best              8. nbfilt
#       9. zp_agn                10. chi2_agn              11. mod_agn               12. mod_star
#      13. chi_star              14. mod_minchi2_phys      15. ebv_minchi2           16. law_minchi2
#      17. age_minchi2           18. mass_minchi2          19. sfr_minchi2           20. ssfr_minchi2
#      21. age_l68               22. age_med               23. age_u68               24. mass_l68
#      25. mass_med              26. mass_u68              27. sfr_l68               28. sfr_med
#      29. sfr_u68               30. ssfr_l68              31. ssfr_med              32. ssfr_u68
#      33. l_nuv                 34. l_r                   35. l_k                   36. mabs_nuv
#      37. mabs_r                38. mabs_j                39. mabs_k                40. flag_chandra
#      41. zpdf_med_space        42. zpdf_l68_space        43. zpdf_u68_space
#
# SE++APER: 148 columns
#       1. mag_aper_f115w         2. mag_aper_f150w         3. mag_aper_f277w         4. mag_aper_f444w
#       5. mag_aper_hst-f814w     6. mag_aper_f770w         7. mag_aper_cfht-u        8. mag_aper_hsc-g
#       9. mag_aper_hsc-r        10. mag_aper_hsc-i        11. mag_aper_hsc-z        12. mag_aper_hsc-y
#      13. mag_aper_hsc-nb0816   14. mag_aper_hsc-nb0921   15. mag_aper_hsc-nb1010   16. mag_aper_uvista-y
#      17. mag_aper_uvista-j     18. mag_aper_uvista-h     19. mag_aper_uvista-ks    20. mag_aper_uvista-nb118
#      21. mag_aper_sc-ia484     22. mag_aper_sc-ia527     23. mag_aper_sc-ia624     24. mag_aper_sc-ia679
#      25. mag_aper_sc-ia738     26. mag_aper_sc-ia767     27. mag_aper_sc-ib427     28. mag_aper_sc-ib505
#      29. mag_aper_sc-ib574     30. mag_aper_sc-ib709     31. mag_aper_sc-ib827     32. mag_aper_sc-nb711
#      33. mag_aper_sc-nb816     34. mag_aper_irac-ch1     35. mag_aper_irac-ch2     36. mag_aper_irac-ch3
#      37. mag_aper_irac-ch4     38. mag_err_aper_f115w    39. mag_err_aper_f150w    40. mag_err_aper_f277w
#      41. mag_err_aper_f444w    42. mag_err_aper_hst-f814w  43. mag_err_aper_f770w    44. mag_err_aper_cfht-u
#      45. mag_err_aper_hsc-g    46. mag_err_aper_hsc-r    47. mag_err_aper_hsc-i    48. mag_err_aper_hsc-z
#      49. mag_err_aper_hsc-y    50. mag_err_aper_hsc-nb0816  51. mag_err_aper_hsc-nb0921  52. mag_err_aper_hsc-nb1010
#      53. mag_err_aper_uvista-y  54. mag_err_aper_uvista-j  55. mag_err_aper_uvista-h  56. mag_err_aper_uvista-ks
#      57. mag_err_aper_uvista-nb118  58. mag_err_aper_sc-ia484  59. mag_err_aper_sc-ia527  60. mag_err_aper_sc-ia624
#      61. mag_err_aper_sc-ia679  62. mag_err_aper_sc-ia738  63. mag_err_aper_sc-ia767  64. mag_err_aper_sc-ib427
#      65. mag_err_aper_sc-ib505  66. mag_err_aper_sc-ib574  67. mag_err_aper_sc-ib709  68. mag_err_aper_sc-ib827
#      69. mag_err_aper_sc-nb711  70. mag_err_aper_sc-nb816  71. mag_err_aper_irac-ch1  72. mag_err_aper_irac-ch2
#      73. mag_err_aper_irac-ch3  74. mag_err_aper_irac-ch4  75. flux_aper_f115w       76. flux_aper_f150w
#      77. flux_aper_f277w       78. flux_aper_f444w       79. flux_aper_hst-f814w   80. flux_aper_f770w
#      81. flux_aper_cfht-u      82. flux_aper_hsc-g       83. flux_aper_hsc-r       84. flux_aper_hsc-i
#      85. flux_aper_hsc-z       86. flux_aper_hsc-y       87. flux_aper_hsc-nb0816  88. flux_aper_hsc-nb0921
#      89. flux_aper_hsc-nb1010  90. flux_aper_uvista-y    91. flux_aper_uvista-j    92. flux_aper_uvista-h
#      93. flux_aper_uvista-ks   94. flux_aper_uvista-nb118  95. flux_aper_sc-ia484    96. flux_aper_sc-ia527
#      97. flux_aper_sc-ia624    98. flux_aper_sc-ia679    99. flux_aper_sc-ia738   100. flux_aper_sc-ia767
#     101. flux_aper_sc-ib427   102. flux_aper_sc-ib505   103. flux_aper_sc-ib574   104. flux_aper_sc-ib709
#     105. flux_aper_sc-ib827   106. flux_aper_sc-nb711   107. flux_aper_sc-nb816   108. flux_aper_irac-ch1
#     109. flux_aper_irac-ch2   110. flux_aper_irac-ch3   111. flux_aper_irac-ch4   112. flux_err_aper_f115w
#     113. flux_err_aper_f150w  114. flux_err_aper_f277w  115. flux_err_aper_f444w  116. flux_err_aper_hst-f814w
#     117. flux_err_aper_f770w  118. flux_err_aper_cfht-u 119. flux_err_aper_hsc-g  120. flux_err_aper_hsc-r
#     121. flux_err_aper_hsc-i  122. flux_err_aper_hsc-z  123. flux_err_aper_hsc-y  124. flux_err_aper_hsc-nb0816
#     125. flux_err_aper_hsc-nb0921 126. flux_err_aper_hsc-nb1010 127. flux_err_aper_uvista-y 128. flux_err_aper_uvista-j
#     129. flux_err_aper_uvista-h 130. flux_err_aper_uvista-ks 131. flux_err_aper_uvista-nb118 132. flux_err_aper_sc-ia484
#     133. flux_err_aper_sc-ia527 134. flux_err_aper_sc-ia624 135. flux_err_aper_sc-ia679 136. flux_err_aper_sc-ia738
#     137. flux_err_aper_sc-ia767 138. flux_err_aper_sc-ib427 139. flux_err_aper_sc-ib505 140. flux_err_aper_sc-ib574
#     141. flux_err_aper_sc-ib709 142. flux_err_aper_sc-ib827 143. flux_err_aper_sc-nb711 144. flux_err_aper_sc-nb816
#     145. flux_err_aper_irac-ch1 146. flux_err_aper_irac-ch2 147. flux_err_aper_irac-ch3 148. flux_err_aper_irac-ch4
#
# CIGALE: 54 columns
#       1. age_form               2. age_form_err           3. sfr_mass_vector_dir    4. sfr_mass_vector_dir_err
#       5. sfh_sfr_bin1           6. sfh_sfr_bin1_err       7. sfh_sfr_bin2           8. sfh_sfr_bin2_err
#       9. sfh_sfr_bin3          10. sfh_sfr_bin3_err      11. sfh_sfr_bin4          12. sfh_sfr_bin4_err
#      13. sfh_sfr_bin5          14. sfh_sfr_bin5_err      15. sfh_sfr_bin6          16. sfh_sfr_bin6_err
#      17. sfh_sfr_bin7          18. sfh_sfr_bin7_err      19. sfh_sfr_bin8          20. sfh_sfr_bin8_err
#      21. sfh_sfr_bin9          22. sfh_sfr_bin9_err      23. sfr_mass_vector_norm  24. sfr_mass_vector_norm_err
#      25. sfh_time_bin1         26. sfh_time_bin1_err     27. sfh_time_bin2         28. sfh_time_bin2_err
#      29. sfh_time_bin3         30. sfh_time_bin3_err     31. sfh_time_bin4         32. sfh_time_bin4_err
#      33. sfh_time_bin5         34. sfh_time_bin5_err     35. sfh_time_bin6         36. sfh_time_bin6_err
#      37. sfh_time_bin7         38. sfh_time_bin7_err     39. sfh_time_bin8         40. sfh_time_bin8_err
#      41. sfh_time_bin9         42. sfh_time_bin9_err     43. metallicity           44. metallicity_err
#      45. sfh_integrated        46. sfh_integrated_err    47. sfr_inst              48. sfr_inst_err
#      49. sfr_100myr            50. sfr_100myr_err        51. mass                  52. mass_err
#      53. chi2_best_fit         54. chi2_red_best_fit
#
# ML-MORPHO: 150 columns
#       1. sph_0_f150w            2. disk_0_f150w           3. irr_0_f150w            4. bd_0_f150w
#       5. sph_1_f150w            6. disk_1_f150w           7. irr_1_f150w            8. bd_1_f150w
#       9. sph_2_f150w           10. disk_2_f150w          11. irr_2_f150w           12. bd_2_f150w
#      13. sph_3_f150w           14. disk_3_f150w          15. irr_3_f150w           16. bd_3_f150w
#      17. sph_4_f150w           18. disk_4_f150w          19. irr_4_f150w           20. bd_4_f150w
#      21. sph_5_f150w           22. disk_5_f150w          23. irr_5_f150w           24. bd_5_f150w
#      25. sph_6_f150w           26. disk_6_f150w          27. irr_6_f150w           28. bd_6_f150w
#      29. sph_7_f150w           30. disk_7_f150w          31. irr_7_f150w           32. bd_7_f150w
#      33. sph_8_f150w           34. disk_8_f150w          35. irr_8_f150w           36. bd_8_f150w
#      37. sph_9_f150w           38. disk_9_f150w          39. irr_9_f150w           40. bd_9_f150w
#      41. sph_0_f277w           42. disk_0_f277w          43. irr_0_f277w           44. bd_0_f277w
#      45. sph_1_f277w           46. disk_1_f277w          47. irr_1_f277w           48. bd_1_f277w
#      49. sph_2_f277w           50. disk_2_f277w          51. irr_2_f277w           52. bd_2_f277w
#      53. sph_3_f277w           54. disk_3_f277w          55. irr_3_f277w           56. bd_3_f277w
#      57. sph_4_f277w           58. disk_4_f277w          59. irr_4_f277w           60. bd_4_f277w
#      61. sph_5_f277w           62. disk_5_f277w          63. irr_5_f277w           64. bd_5_f277w
#      65. sph_6_f277w           66. disk_6_f277w          67. irr_6_f277w           68. bd_6_f277w
#      69. sph_7_f277w           70. disk_7_f277w          71. irr_7_f277w           72. bd_7_f277w
#      73. sph_8_f277w           74. disk_8_f277w          75. irr_8_f277w           76. bd_8_f277w
#      77. sph_9_f277w           78. disk_9_f277w          79. irr_9_f277w           80. bd_9_f277w
#      81. sph_0_f444w           82. disk_0_f444w          83. irr_0_f444w           84. bd_0_f444w
#      85. sph_1_f444w           86. disk_1_f444w          87. irr_1_f444w           88. bd_1_f444w
#      89. sph_2_f444w           90. disk_2_f444w          91. irr_2_f444w           92. bd_2_f444w
#      93. sph_3_f444w           94. disk_3_f444w          95. irr_3_f444w           96. bd_3_f444w
#      97. sph_4_f444w           98. disk_4_f444w          99. irr_4_f444w          100. bd_4_f444w
#     101. sph_5_f444w          102. disk_5_f444w         103. irr_5_f444w          104. bd_5_f444w
#     105. sph_6_f444w          106. disk_6_f444w         107. irr_6_f444w          108. bd_6_f444w
#     109. sph_7_f444w          110. disk_7_f444w         111. irr_7_f444w          112. bd_7_f444w
#     113. sph_8_f444w          114. disk_8_f444w         115. irr_8_f444w          116. bd_8_f444w
#     117. sph_9_f444w          118. disk_9_f444w         119. irr_9_f444w          120. bd_9_f444w
#     121. sph_f150w_mean       122. sph_f150w_std        123. disk_f150w_mean      124. disk_f150w_std
#     125. irr_f150w_mean       126. irr_f150w_std        127. bd_f150w_mean        128. bd_f150w_std
#     129. sph_f277w_mean       130. sph_f277w_std        131. disk_f277w_mean      132. disk_f277w_std
#     133. irr_f277w_mean       134. irr_f277w_std        135. bd_f277w_mean        136. bd_f277w_std
#     137. sph_f444w_mean       138. sph_f444w_std        139. disk_f444w_mean      140. disk_f444w_std
#     141. irr_f444w_mean       142. irr_f444w_std        143. bd_f444w_mean        144. bd_f444w_std
#     145. morph_flag_f277w     146. delta_f277w          147. morph_flag_f444w     148. delta_f444w
#     149. morph_flag_f150w     150. delta_f150w
#
# B+D: 461 columns
#       1. ra_detec_bd            2. dec_detec_bd           3. disk_radius_deg        4. disk_radius_deg_err
#       5. bulge_radius_deg       6. bulge_radius_deg_err   7. angle_bd               8. angle_bd_err
#       9. disk_axratio          10. disk_axratio_err      11. bulge_axratio         12. bulge_axratio_err
#      13. fmf_b+d_chi2          14. mag_model_bd_total_f115w  15. mag_model_bd_total_f150w  16. mag_model_bd_total_f277w
#      17. mag_model_bd_total_f444w  18. mag_err_model_bd_total_f115w  19. mag_err_model_bd_total_f150w  20. mag_err_model_bd_total_f277w
#      21. mag_err_model_bd_total_f444w  22. mag_model_bulge_f115w  23. mag_model_bulge_f150w  24. mag_model_bulge_f277w
#      25. mag_model_bulge_f444w  26. mag_err_model_bulge_f115w  27. mag_err_model_bulge_f150w  28. mag_err_model_bulge_f277w
#      29. mag_err_model_bulge_f444w  30. mag_model_disk_f115w  31. mag_model_disk_f150w  32. mag_model_disk_f277w
#      33. mag_model_disk_f444w  34. mag_err_model_disk_f115w  35. mag_err_model_disk_f150w  36. mag_err_model_disk_f277w
#      37. mag_err_model_disk_f444w  38. flux_model_bd_total_f115w  39. flux_model_bd_total_f150w  40. flux_model_bd_total_f277w
#      41. flux_model_bd_total_f444w  42. flux_err_model_bd_total_f115w  43. flux_err_model_bd_total_f150w  44. flux_err_model_bd_total_f277w
#      45. flux_err_model_bd_total_f444w  46. flux_model_bulge_f115w  47. flux_model_bulge_f150w  48. flux_model_bulge_f277w
#      49. flux_model_bulge_f444w  50. flux_err_model_bulge_f115w  51. flux_err_model_bulge_f150w  52. flux_err_model_bulge_f277w
#      53. flux_err_model_bulge_f444w  54. flux_model_disk_f115w  55. flux_model_disk_f150w  56. flux_model_disk_f277w
#      57. flux_model_disk_f444w  58. flux_err_model_disk_f115w  59. flux_err_model_disk_f150w  60. flux_err_model_disk_f277w
#      61. flux_err_model_disk_f444w  62. b/t_f115w             63. b/t_f150w             64. b/t_f277w
#      65. b/t_f444w             66. b/t_err_f115w         67. b/t_err_f150w         68. b/t_err_f277w
#      69. b/t_err_f444w         70. mag_model_bd_total_hst-f814w  71. mag_model_bd_total_f770w  72. mag_model_bd_total_cfht-u
#      73. mag_model_bd_total_hsc-g  74. mag_model_bd_total_hsc-r  75. mag_model_bd_total_hsc-i  76. mag_model_bd_total_hsc-z
#      77. mag_model_bd_total_hsc-y  78. mag_model_bd_total_hsc-nb0816  79. mag_model_bd_total_hsc-nb0921  80. mag_model_bd_total_hsc-nb1010
#      81. mag_model_bd_total_uvista-y  82. mag_model_bd_total_uvista-j  83. mag_model_bd_total_uvista-h  84. mag_model_bd_total_uvista-ks
#      85. mag_model_bd_total_sc-ia484  86. mag_model_bd_total_sc-ia527  87. mag_model_bd_total_sc-ia624  88. mag_model_bd_total_sc-ia679
#      89. mag_model_bd_total_sc-ia738  90. mag_model_bd_total_sc-ia767  91. mag_model_bd_total_sc-ib427  92. mag_model_bd_total_sc-ib505
#      93. mag_model_bd_total_sc-ib574  94. mag_model_bd_total_sc-ib709  95. mag_model_bd_total_sc-ib827  96. mag_model_bd_total_sc-nb711
#      97. mag_model_bd_total_sc-nb816  98. mag_err_model_bd_total_hst-f814w  99. mag_err_model_bd_total_f770w 100. mag_err_model_bd_total_cfht-u
#     101. mag_err_model_bd_total_hsc-g 102. mag_err_model_bd_total_hsc-r 103. mag_err_model_bd_total_hsc-i 104. mag_err_model_bd_total_hsc-z
#     105. mag_err_model_bd_total_hsc-y 106. mag_err_model_bd_total_hsc-nb0816 107. mag_err_model_bd_total_hsc-nb0921 108. mag_err_model_bd_total_hsc-nb1010
#     109. mag_err_model_bd_total_uvista-y 110. mag_err_model_bd_total_uvista-j 111. mag_err_model_bd_total_uvista-h 112. mag_err_model_bd_total_uvista-ks
#     113. mag_err_model_bd_total_sc-ia484 114. mag_err_model_bd_total_sc-ia527 115. mag_err_model_bd_total_sc-ia624 116. mag_err_model_bd_total_sc-ia679
#     117. mag_err_model_bd_total_sc-ia738 118. mag_err_model_bd_total_sc-ia767 119. mag_err_model_bd_total_sc-ib427 120. mag_err_model_bd_total_sc-ib505
#     121. mag_err_model_bd_total_sc-ib574 122. mag_err_model_bd_total_sc-ib709 123. mag_err_model_bd_total_sc-ib827 124. mag_err_model_bd_total_sc-nb711
#     125. mag_err_model_bd_total_sc-nb816 126. mag_model_bulge_hst-f814w 127. mag_model_bulge_f770w 128. mag_model_bulge_cfht-u
#     129. mag_model_bulge_hsc-g 130. mag_model_bulge_hsc-r 131. mag_model_bulge_hsc-i 132. mag_model_bulge_hsc-z
#     133. mag_model_bulge_hsc-y 134. mag_model_bulge_hsc-nb0816 135. mag_model_bulge_hsc-nb0921 136. mag_model_bulge_hsc-nb1010
#     137. mag_model_bulge_uvista-y 138. mag_model_bulge_uvista-j 139. mag_model_bulge_uvista-h 140. mag_model_bulge_uvista-ks
#     141. mag_model_bulge_sc-ia484 142. mag_model_bulge_sc-ia527 143. mag_model_bulge_sc-ia624 144. mag_model_bulge_sc-ia679
#     145. mag_model_bulge_sc-ia738 146. mag_model_bulge_sc-ia767 147. mag_model_bulge_sc-ib427 148. mag_model_bulge_sc-ib505
#     149. mag_model_bulge_sc-ib574 150. mag_model_bulge_sc-ib709 151. mag_model_bulge_sc-ib827 152. mag_model_bulge_sc-nb711
#     153. mag_model_bulge_sc-nb816 154. mag_err_model_bulge_hst-f814w 155. mag_err_model_bulge_f770w 156. mag_err_model_bulge_cfht-u
#     157. mag_err_model_bulge_hsc-g 158. mag_err_model_bulge_hsc-r 159. mag_err_model_bulge_hsc-i 160. mag_err_model_bulge_hsc-z
#     161. mag_err_model_bulge_hsc-y 162. mag_err_model_bulge_hsc-nb0816 163. mag_err_model_bulge_hsc-nb0921 164. mag_err_model_bulge_hsc-nb1010
#     165. mag_err_model_bulge_uvista-y 166. mag_err_model_bulge_uvista-j 167. mag_err_model_bulge_uvista-h 168. mag_err_model_bulge_uvista-ks
#     169. mag_err_model_bulge_sc-ia484 170. mag_err_model_bulge_sc-ia527 171. mag_err_model_bulge_sc-ia624 172. mag_err_model_bulge_sc-ia679
#     173. mag_err_model_bulge_sc-ia738 174. mag_err_model_bulge_sc-ia767 175. mag_err_model_bulge_sc-ib427 176. mag_err_model_bulge_sc-ib505
#     177. mag_err_model_bulge_sc-ib574 178. mag_err_model_bulge_sc-ib709 179. mag_err_model_bulge_sc-ib827 180. mag_err_model_bulge_sc-nb711
#     181. mag_err_model_bulge_sc-nb816 182. mag_model_disk_hst-f814w 183. mag_model_disk_f770w 184. mag_model_disk_cfht-u
#     185. mag_model_disk_hsc-g 186. mag_model_disk_hsc-r 187. mag_model_disk_hsc-i 188. mag_model_disk_hsc-z
#     189. mag_model_disk_hsc-y 190. mag_model_disk_hsc-nb0816 191. mag_model_disk_hsc-nb0921 192. mag_model_disk_hsc-nb1010
#     193. mag_model_disk_uvista-y 194. mag_model_disk_uvista-j 195. mag_model_disk_uvista-h 196. mag_model_disk_uvista-ks
#     197. mag_model_disk_sc-ia484 198. mag_model_disk_sc-ia527 199. mag_model_disk_sc-ia624 200. mag_model_disk_sc-ia679
#     201. mag_model_disk_sc-ia738 202. mag_model_disk_sc-ia767 203. mag_model_disk_sc-ib427 204. mag_model_disk_sc-ib505
#     205. mag_model_disk_sc-ib574 206. mag_model_disk_sc-ib709 207. mag_model_disk_sc-ib827 208. mag_model_disk_sc-nb711
#     209. mag_model_disk_sc-nb816 210. mag_err_model_disk_hst-f814w 211. mag_err_model_disk_f770w 212. mag_err_model_disk_cfht-u
#     213. mag_err_model_disk_hsc-g 214. mag_err_model_disk_hsc-r 215. mag_err_model_disk_hsc-i 216. mag_err_model_disk_hsc-z
#     217. mag_err_model_disk_hsc-y 218. mag_err_model_disk_hsc-nb0816 219. mag_err_model_disk_hsc-nb0921 220. mag_err_model_disk_hsc-nb1010
#     221. mag_err_model_disk_uvista-y 222. mag_err_model_disk_uvista-j 223. mag_err_model_disk_uvista-h 224. mag_err_model_disk_uvista-ks
#     225. mag_err_model_disk_sc-ia484 226. mag_err_model_disk_sc-ia527 227. mag_err_model_disk_sc-ia624 228. mag_err_model_disk_sc-ia679
#     229. mag_err_model_disk_sc-ia738 230. mag_err_model_disk_sc-ia767 231. mag_err_model_disk_sc-ib427 232. mag_err_model_disk_sc-ib505
#     233. mag_err_model_disk_sc-ib574 234. mag_err_model_disk_sc-ib709 235. mag_err_model_disk_sc-ib827 236. mag_err_model_disk_sc-nb711
#     237. mag_err_model_disk_sc-nb816 238. flux_model_bd_total_hst-f814w 239. flux_model_bd_total_f770w 240. flux_model_bd_total_cfht-u
#     241. flux_model_bd_total_hsc-g 242. flux_model_bd_total_hsc-r 243. flux_model_bd_total_hsc-i 244. flux_model_bd_total_hsc-z
#     245. flux_model_bd_total_hsc-y 246. flux_model_bd_total_hsc-nb0816 247. flux_model_bd_total_hsc-nb0921 248. flux_model_bd_total_hsc-nb1010
#     249. flux_model_bd_total_uvista-y 250. flux_model_bd_total_uvista-j 251. flux_model_bd_total_uvista-h 252. flux_model_bd_total_uvista-ks
#     253. flux_model_bd_total_sc-ia484 254. flux_model_bd_total_sc-ia527 255. flux_model_bd_total_sc-ia624 256. flux_model_bd_total_sc-ia679
#     257. flux_model_bd_total_sc-ia738 258. flux_model_bd_total_sc-ia767 259. flux_model_bd_total_sc-ib427 260. flux_model_bd_total_sc-ib505
#     261. flux_model_bd_total_sc-ib574 262. flux_model_bd_total_sc-ib709 263. flux_model_bd_total_sc-ib827 264. flux_model_bd_total_sc-nb711
#     265. flux_model_bd_total_sc-nb816 266. flux_err_model_bd_total_hst-f814w 267. flux_err_model_bd_total_f770w 268. flux_err_model_bd_total_cfht-u
#     269. flux_err_model_bd_total_hsc-g 270. flux_err_model_bd_total_hsc-r 271. flux_err_model_bd_total_hsc-i 272. flux_err_model_bd_total_hsc-z
#     273. flux_err_model_bd_total_hsc-y 274. flux_err_model_bd_total_hsc-nb0816 275. flux_err_model_bd_total_hsc-nb0921 276. flux_err_model_bd_total_hsc-nb1010
#     277. flux_err_model_bd_total_uvista-y 278. flux_err_model_bd_total_uvista-j 279. flux_err_model_bd_total_uvista-h 280. flux_err_model_bd_total_uvista-ks
#     281. flux_err_model_bd_total_sc-ia484 282. flux_err_model_bd_total_sc-ia527 283. flux_err_model_bd_total_sc-ia624 284. flux_err_model_bd_total_sc-ia679
#     285. flux_err_model_bd_total_sc-ia738 286. flux_err_model_bd_total_sc-ia767 287. flux_err_model_bd_total_sc-ib427 288. flux_err_model_bd_total_sc-ib505
#     289. flux_err_model_bd_total_sc-ib574 290. flux_err_model_bd_total_sc-ib709 291. flux_err_model_bd_total_sc-ib827 292. flux_err_model_bd_total_sc-nb711
#     293. flux_err_model_bd_total_sc-nb816 294. flux_model_bulge_hst-f814w 295. flux_model_bulge_f770w 296. flux_model_bulge_cfht-u
#     297. flux_model_bulge_hsc-g 298. flux_model_bulge_hsc-r 299. flux_model_bulge_hsc-i 300. flux_model_bulge_hsc-z
#     301. flux_model_bulge_hsc-y 302. flux_model_bulge_hsc-nb0816 303. flux_model_bulge_hsc-nb0921 304. flux_model_bulge_hsc-nb1010
#     305. flux_model_bulge_uvista-y 306. flux_model_bulge_uvista-j 307. flux_model_bulge_uvista-h 308. flux_model_bulge_uvista-ks
#     309. flux_model_bulge_sc-ia484 310. flux_model_bulge_sc-ia527 311. flux_model_bulge_sc-ia624 312. flux_model_bulge_sc-ia679
#     313. flux_model_bulge_sc-ia738 314. flux_model_bulge_sc-ia767 315. flux_model_bulge_sc-ib427 316. flux_model_bulge_sc-ib505
#     317. flux_model_bulge_sc-ib574 318. flux_model_bulge_sc-ib709 319. flux_model_bulge_sc-ib827 320. flux_model_bulge_sc-nb711
#     321. flux_model_bulge_sc-nb816 322. flux_err_model_bulge_hst-f814w 323. flux_err_model_bulge_f770w 324. flux_err_model_bulge_cfht-u
#     325. flux_err_model_bulge_hsc-g 326. flux_err_model_bulge_hsc-r 327. flux_err_model_bulge_hsc-i 328. flux_err_model_bulge_hsc-z
#     329. flux_err_model_bulge_hsc-y 330. flux_err_model_bulge_hsc-nb0816 331. flux_err_model_bulge_hsc-nb0921 332. flux_err_model_bulge_hsc-nb1010
#     333. flux_err_model_bulge_uvista-y 334. flux_err_model_bulge_uvista-j 335. flux_err_model_bulge_uvista-h 336. flux_err_model_bulge_uvista-ks
#     337. flux_err_model_bulge_sc-ia484 338. flux_err_model_bulge_sc-ia527 339. flux_err_model_bulge_sc-ia624 340. flux_err_model_bulge_sc-ia679
#     341. flux_err_model_bulge_sc-ia738 342. flux_err_model_bulge_sc-ia767 343. flux_err_model_bulge_sc-ib427 344. flux_err_model_bulge_sc-ib505
#     345. flux_err_model_bulge_sc-ib574 346. flux_err_model_bulge_sc-ib709 347. flux_err_model_bulge_sc-ib827 348. flux_err_model_bulge_sc-nb711
#     349. flux_err_model_bulge_sc-nb816 350. flux_model_disk_hst-f814w 351. flux_model_disk_f770w 352. flux_model_disk_cfht-u
#     353. flux_model_disk_hsc-g 354. flux_model_disk_hsc-r 355. flux_model_disk_hsc-i 356. flux_model_disk_hsc-z
#     357. flux_model_disk_hsc-y 358. flux_model_disk_hsc-nb0816 359. flux_model_disk_hsc-nb0921 360. flux_model_disk_hsc-nb1010
#     361. flux_model_disk_uvista-y 362. flux_model_disk_uvista-j 363. flux_model_disk_uvista-h 364. flux_model_disk_uvista-ks
#     365. flux_model_disk_sc-ia484 366. flux_model_disk_sc-ia527 367. flux_model_disk_sc-ia624 368. flux_model_disk_sc-ia679
#     369. flux_model_disk_sc-ia738 370. flux_model_disk_sc-ia767 371. flux_model_disk_sc-ib427 372. flux_model_disk_sc-ib505
#     373. flux_model_disk_sc-ib574 374. flux_model_disk_sc-ib709 375. flux_model_disk_sc-ib827 376. flux_model_disk_sc-nb711
#     377. flux_model_disk_sc-nb816 378. flux_err_model_disk_hst-f814w 379. flux_err_model_disk_f770w 380. flux_err_model_disk_cfht-u
#     381. flux_err_model_disk_hsc-g 382. flux_err_model_disk_hsc-r 383. flux_err_model_disk_hsc-i 384. flux_err_model_disk_hsc-z
#     385. flux_err_model_disk_hsc-y 386. flux_err_model_disk_hsc-nb0816 387. flux_err_model_disk_hsc-nb0921 388. flux_err_model_disk_hsc-nb1010
#     389. flux_err_model_disk_uvista-y 390. flux_err_model_disk_uvista-j 391. flux_err_model_disk_uvista-h 392. flux_err_model_disk_uvista-ks
#     393. flux_err_model_disk_sc-ia484 394. flux_err_model_disk_sc-ia527 395. flux_err_model_disk_sc-ia624 396. flux_err_model_disk_sc-ia679
#     397. flux_err_model_disk_sc-ia738 398. flux_err_model_disk_sc-ia767 399. flux_err_model_disk_sc-ib427 400. flux_err_model_disk_sc-ib505
#     401. flux_err_model_disk_sc-ib574 402. flux_err_model_disk_sc-ib709 403. flux_err_model_disk_sc-ib827 404. flux_err_model_disk_sc-nb711
#     405. flux_err_model_disk_sc-nb816 406. b/t_hst-f814w        407. b/t_f770w            408. b/t_cfht-u
#     409. b/t_hsc-g            410. b/t_hsc-r            411. b/t_hsc-i            412. b/t_hsc-z
#     413. b/t_hsc-y            414. b/t_hsc-nb0816       415. b/t_hsc-nb0921       416. b/t_hsc-nb1010
#     417. b/t_uvista-y         418. b/t_uvista-j         419. b/t_uvista-h         420. b/t_uvista-ks
#     421. b/t_sc-ia484         422. b/t_sc-ia527         423. b/t_sc-ia624         424. b/t_sc-ia679
#     425. b/t_sc-ia738         426. b/t_sc-ia767         427. b/t_sc-ib427         428. b/t_sc-ib505
#     429. b/t_sc-ib574         430. b/t_sc-ib709         431. b/t_sc-ib827         432. b/t_sc-nb711
#     433. b/t_sc-nb816         434. b/t_err_hst-f814w    435. b/t_err_f770w        436. b/t_err_cfht-u
#     437. b/t_err_hsc-g        438. b/t_err_hsc-r        439. b/t_err_hsc-i        440. b/t_err_hsc-z
#     441. b/t_err_hsc-y        442. b/t_err_hsc-nb0816   443. b/t_err_hsc-nb0921   444. b/t_err_hsc-nb1010
#     445. b/t_err_uvista-y     446. b/t_err_uvista-j     447. b/t_err_uvista-h     448. b/t_err_uvista-ks
#     449. b/t_err_sc-ia484     450. b/t_err_sc-ia527     451. b/t_err_sc-ia624     452. b/t_err_sc-ia679
#     453. b/t_err_sc-ia738     454. b/t_err_sc-ia767     455. b/t_err_sc-ib427     456. b/t_err_sc-ib505
#     457. b/t_err_sc-ib574     458. b/t_err_sc-ib709     459. b/t_err_sc-ib827     460. b/t_err_sc-nb711
#     461. b/t_err_sc-nb816
#
# ====================================================================================================
# === SEARCHING ALL CATALOGS FOR KEY COLUMNS ===
#
# ID:
#   PHOTOMETRY HOTCOLD AND SE++: id_specz_khostovan25, group_id, id, segment-id
#
# COORDINATES:
#   PHOTOMETRY HOTCOLD AND SE++: radius_sersic_err, flux_err-uncal_model_irac-ch4, dec_model, flux_err-uncal_model_irac-ch3, axratio_sersic
#     ... and 24 more
#   LEPHARE: flag_chandra
#   SE++APER: mag_aper_irac-ch3, mag_err_aper_irac-ch3, mag_err_aper_irac-ch1, mag_aper_irac-ch2, mag_err_aper_irac-ch4
#     ... and 11 more
#   CIGALE: sfh_integrated_err, sfh_integrated
#   ML-MORPHO: delta_f444w, delta_f150w, delta_f277w
#   B+D: bulge_axratio, disk_axratio_err, bulge_axratio_err, disk_radius_deg_err, dec_detec_bd
#     ... and 5 more
#
# REDSHIFT:
#   PHOTOMETRY HOTCOLD AND SE++: mag_err_model_hsc-z, flux_model_hsc-z, id_specz_khostovan25, mag_model_hsc-z, flux_err-uncal_model_hsc-z
#     ... and 1 more
#   LEPHARE: zpdf_u68_space, zpdf_u68, zp_agn, zpdf_med_space, zfinal
#     ... and 4 more
#   SE++APER: mag_aper_hsc-z, mag_err_aper_hsc-z, flux_aper_hsc-z, flux_err_aper_hsc-z
#   B+D: flux_model_bd_total_hsc-z, mag_model_bulge_hsc-z, mag_err_model_bulge_hsc-z, flux_err_model_bulge_hsc-z, b/t_hsc-z
#     ... and 9 more
#
# STELLAR_MASS:
#   LEPHARE: mass_med, mass_minchi2, mass_l68, mass_u68
#   CIGALE: mass_err, mass, sfr_mass_vector_dir_err, sfr_mass_vector_dir, sfr_mass_vector_norm_err
#     ... and 1 more
#
# SFR:
#   LEPHARE: ssfr_minchi2, ssfr_u68, ssfr_med, ssfr_l68, sfr_med
#     ... and 3 more
#   CIGALE: sfh_sfr_bin2_err, sfh_sfr_bin6, sfr_inst_err, sfh_sfr_bin7, sfh_sfr_bin3_err
#     ... and 21 more
#
# SIZE:
#   PHOTOMETRY HOTCOLD AND SE++: radius_sersic_err, kron_f770w_psf_corr, kron2_a, seg_area, kron_rad
#     ... and 9 more
#   CIGALE: chi2_red_best_fit
#   B+D: bulge_radius_deg, bulge_radius_deg_err, disk_radius_deg, disk_radius_deg_err
#
# MAGNITUDE:
#   PHOTOMETRY HOTCOLD AND SE++: flux_err-uncal_model_sc-ib709, mag_err_model_sc-ia527, flux_err-cal_model_hsc-nb0816, flux_model_uvista-y, mag_aper_f150w
#     ... and 224 more
#   LEPHARE: mabs_nuv, mabs_k, mabs_j, mabs_r
#   SE++APER: mag_aper_sc-ia527, mag_err_aper_irac-ch4, flux_err_aper_irac-ch2, mag_aper_f150w, mag_aper_sc-ib427
#     ... and 143 more
#   B+D: flux_err_model_disk_sc-ib505, flux_model_bd_total_sc-ib427, flux_err_model_disk_sc-ia624, mag_model_bd_total_f277w, flux_model_bulge_sc-ib427
#     ... and 381 more
#
# COLORS:
#   SE++APER: mag_aper_irac-ch3, mag_err_aper_irac-ch3, mag_err_aper_irac-ch1, mag_aper_irac-ch2, mag_err_aper_irac-ch4
#     ... and 11 more
#   CIGALE: sfr_inst_err, sfr_inst
#
# MORPHOLOGY:
#   PHOTOMETRY HOTCOLD AND SE++: radius_sersic_err, axratio_sersic_err, angle_sersic_err, sersic, sersic_err
#     ... and 7 more
#   LEPHARE: type, flag_chandra
#   ML-MORPHO: morph_flag_f150w, morph_flag_f277w, morph_flag_f444w
#
# PHOTOMETRY:
#   PHOTOMETRY HOTCOLD AND SE++: flux_auto_hst-f814w, mu_max_hst-f814w, flux_err-uncal_model_irac-ch4, flux_err-uncal_model_uvista-ks, mag_err_model_hst-f814w
#     ... and 34 more
#   SE++APER: mag_err_aper_irac-ch3, mag_aper_irac-ch2, mag_err_aper_irac-ch4, flux_err_aper_irac-ch2, mag_err_aper_uvista-ks
#     ... and 19 more
#   B+D: mag_err_model_disk_hst-f814w, mag_model_disk_hst-f814w, flux_model_bd_total_uvista-ks, mag_err_model_bd_total_hst-f814w, flux_model_disk_hst-f814w
#     ... and 23 more
#
# ENVIRONMENT:
#   PHOTOMETRY HOTCOLD AND SE++: group_id
#
# QUALITY:
#   PHOTOMETRY HOTCOLD AND SE++: fmf_chi2, flag_blend, flag_star_hsc, chi2_max, warn_flag
#     ... and 1 more
#   LEPHARE: ssfr_minchi2, chi2_agn, mod_minchi2_phys, chi2_best, law_minchi2
#     ... and 7 more
#   CIGALE: chi2_red_best_fit, chi2_best_fit
#   ML-MORPHO: morph_flag_f150w, morph_flag_f277w, morph_flag_f444w
#   B+D: fmf_b+d_chi2
#
# ====================================================================================================
# === SUGGESTED COLUMN MAPPING ===
# Recommended columns for analysis:
# column_mapping = {
#     'id': ('PHOTOMETRY HOTCOLD AND SE++', 'id_specz_khostovan25'), # alternatives: group_id, id, segment-id
#     'coordinates': ('PHOTOMETRY HOTCOLD AND SE++', 'radius_sersic_err'), # alternatives: flux_err-uncal_model_irac-ch4, dec_model, flux_err-uncal_model_irac-ch3, axratio_sersic
#     'redshift': ('B+D', 'flux_model_bd_total_hsc-z'), # alternatives: mag_model_bulge_hsc-z, mag_err_model_bulge_hsc-z, flux_err_model_bulge_hsc-z, b/t_hsc-z
#     'stellar_mass': ('CIGALE', 'mass_err'), # alternatives: mass, sfr_mass_vector_dir_err, sfr_mass_vector_dir, sfr_mass_vector_norm_err
#     'sfr': ('CIGALE', 'sfh_sfr_bin2_err'), # alternatives: sfh_sfr_bin6, sfr_inst_err, sfh_sfr_bin7, sfh_sfr_bin3_err
#     'size': ('PHOTOMETRY HOTCOLD AND SE++', 'radius_sersic_err'), # alternatives: kron_f770w_psf_corr, kron2_a, seg_area, kron_rad
#     'magnitude': ('B+D', 'flux_err_model_disk_sc-ib505'), # alternatives: flux_model_bd_total_sc-ib427, flux_err_model_disk_sc-ia624, mag_model_bd_total_f277w, flux_model_bulge_sc-ib427
#     'colors': ('SE++APER', 'mag_aper_irac-ch3'), # alternatives: mag_err_aper_irac-ch3, mag_err_aper_irac-ch1, mag_aper_irac-ch2, mag_err_aper_irac-ch4
#     'morphology': ('PHOTOMETRY HOTCOLD AND SE++', 'radius_sersic_err'), # alternatives: axratio_sersic_err, angle_sersic_err, sersic, sersic_err
#     'photometry': ('PHOTOMETRY HOTCOLD AND SE++', 'flux_auto_hst-f814w'), # alternatives: mu_max_hst-f814w, flux_err-uncal_model_irac-ch4, flux_err-uncal_model_uvista-ks, mag_err_model_hst-f814w
#     'environment': ('PHOTOMETRY HOTCOLD AND SE++', 'group_id'),
#     'quality': ('LEPHARE', 'ssfr_minchi2'), # alternatives: chi2_agn, mod_minchi2_phys, chi2_best, law_minchi2
# }

# %% [markdown]
# ## 3. Identify Key Columns for Selection

# %%
# Display all column names to identify the ones we need
print("=== All Available Columns ===")
print(f"Total columns: {len(catalog.colnames)}\n")

# Print columns in groups for readability
cols_per_row = 4
for i in range(0, len(catalog.colnames), cols_per_row):
    row_cols = catalog.colnames[i:i+cols_per_row]
    formatted_cols = [f"{j+i+1:3d}. {col:<20}" for j, col in enumerate(row_cols)]
    print(" ".join(formatted_cols))

print("\n" + "="*80)

# Look for key columns we need (with common naming patterns)
key_patterns = {
    'coordinates': ['RA', 'DEC', 'ra', 'dec', 'ALPHA', 'DELTA'],
    'redshift': ['z', 'Z', 'redshift', 'REDSHIFT', 'z_phot', 'z_spec'],
    'stellar_mass': ['logm', 'mass', 'MASS', 'lmass', 'stellar_mass'],
    'sfr': ['sfr', 'SFR', 'star_formation_rate'],
    'size': ['re', 'RE', 'r_eff', 'radius', 'size'],
    'morphology': ['morph', 'class', 'type', 'flag']
}

print("\n=== Searching for Key Columns ===")
found_cols = {}

for category, patterns in key_patterns.items():
    matches = []
    for pattern in patterns:
        matches.extend([col for col in catalog.colnames if pattern.lower() in col.lower()])
    
    if matches:
        found_cols[category] = list(set(matches))  # Remove duplicates
        print(f"{category.upper():<15}: {', '.join(found_cols[category])}")
    else:
        print(f"{category.upper():<15}: None found")
# Out:
# === All Available Columns ===
# Total columns: 1143
#
#   1. id                     2. segment-id             3. tile                   4. id_specz_khostovan25
#   5. ra                     6. dec                    7. x_image                8. y_image
#   9. a_image               10. b_image               11. theta_image           12. theta_world
#  13. chi2_max              14. mode                  15. snr_hst-f814w         16. wht_hst-f814w
#  17. flux_auto_hst-f814w   18. flux_err_auto_hst-f814w  19. mag_auto_hst-f814w    20. flux_aper_hst-f814w
#  21. flux_err_aper_hst-f814w  22. mag_aper_hst-f814w    23. snr_f115w             24. wht_f115w
#  25. flux_auto_f115w       26. flux_err_auto_f115w   27. mag_auto_f115w        28. flux_aper_f115w
#  29. flux_err_aper_f115w   30. mag_aper_f115w        31. snr_f150w             32. wht_f150w
#  33. flux_auto_f150w       34. flux_err_auto_f150w   35. mag_auto_f150w        36. flux_aper_f150w
#  37. flux_err_aper_f150w   38. mag_aper_f150w        39. snr_f277w             40. wht_f277w
#  41. flux_auto_f277w       42. flux_err_auto_f277w   43. mag_auto_f277w        44. flux_aper_f277w
#  45. flux_err_aper_f277w   46. mag_aper_f277w        47. snr_f444w             48. wht_f444w
#  49. flux_auto_f444w       50. flux_err_auto_f444w   51. mag_auto_f444w        52. flux_aper_f444w
#  53. flux_err_aper_f444w   54. mag_aper_f444w        55. snr_f770w             56. wht_f770w
#  57. flux_auto_f770w       58. flux_err_auto_f770w   59. mag_auto_f770w        60. flux_aper_f770w
#  61. flux_err_aper_f770w   62. mag_aper_f770w        63. c_f444w               64. fwhm
#  65. mu_max_hst-f814w      66. mu_max_f115w          67. mu_max_f150w          68. mu_max_f277w
#  69. mu_max_f444w          70. mu_max_f770w          71. kron_rad              72. kron1_a
#  73. kron1_b               74. kron1_area            75. kron2_a               76. kron2_b
#  77. kron2_area            78. seg_area              79. kron_corr             80. kron_f444w_psf_corr
#  81. kron_f770w_psf_corr   82. kron_f770w_ap_corr    83. flag_star             84. flag_blend
#  85. ra_model              86. dec_model             87. radius_sersic         88. radius_sersic_err
#  89. axratio_sersic        90. axratio_sersic_err    91. sersic                92. sersic_err
#  93. angle_sersic          94. angle_sersic_err      95. e1                    96. e1_err
#  97. e2                    98. e2_err                99. fmf_chi2             100. group_id
# 101. mag_model_f115w      102. mag_model_f150w      103. mag_model_f277w      104. mag_model_f444w
# 105. mag_model_hst-f814w  106. mag_model_f770w      107. mag_model_cfht-u     108. mag_model_hsc-g
# 109. mag_model_hsc-r      110. mag_model_hsc-i      111. mag_model_hsc-z      112. mag_model_hsc-y
# 113. mag_model_hsc-nb0816 114. mag_model_hsc-nb0921 115. mag_model_hsc-nb1010 116. mag_model_uvista-y
# 117. mag_model_uvista-j   118. mag_model_uvista-h   119. mag_model_uvista-ks  120. mag_model_uvista-nb118
# 121. mag_model_sc-ia484   122. mag_model_sc-ia527   123. mag_model_sc-ia624   124. mag_model_sc-ia679
# 125. mag_model_sc-ia738   126. mag_model_sc-ia767   127. mag_model_sc-ib427   128. mag_model_sc-ib505
# 129. mag_model_sc-ib574   130. mag_model_sc-ib709   131. mag_model_sc-ib827   132. mag_model_sc-nb711
# 133. mag_model_sc-nb816   134. mag_model_irac-ch1   135. mag_model_irac-ch2   136. mag_model_irac-ch3
# 137. mag_model_irac-ch4   138. mag_err_model_f115w  139. mag_err_model_f150w  140. mag_err_model_f277w
# 141. mag_err_model_f444w  142. mag_err_model_hst-f814w 143. mag_err_model_f770w  144. mag_err_model_cfht-u
# 145. mag_err_model_hsc-g  146. mag_err_model_hsc-r  147. mag_err_model_hsc-i  148. mag_err_model_hsc-z
# 149. mag_err_model_hsc-y  150. mag_err_model_hsc-nb0816 151. mag_err_model_hsc-nb0921 152. mag_err_model_hsc-nb1010
# 153. mag_err_model_uvista-y 154. mag_err_model_uvista-j 155. mag_err_model_uvista-h 156. mag_err_model_uvista-ks
# 157. mag_err_model_uvista-nb118 158. mag_err_model_sc-ia484 159. mag_err_model_sc-ia527 160. mag_err_model_sc-ia624
# 161. mag_err_model_sc-ia679 162. mag_err_model_sc-ia738 163. mag_err_model_sc-ia767 164. mag_err_model_sc-ib427
# 165. mag_err_model_sc-ib505 166. mag_err_model_sc-ib574 167. mag_err_model_sc-ib709 168. mag_err_model_sc-ib827
# 169. mag_err_model_sc-nb711 170. mag_err_model_sc-nb816 171. mag_err_model_irac-ch1 172. mag_err_model_irac-ch2
# 173. mag_err_model_irac-ch3 174. mag_err_model_irac-ch4 175. flux_model_f115w     176. flux_model_f150w
# 177. flux_model_f277w     178. flux_model_f444w     179. flux_model_hst-f814w 180. flux_model_f770w
# 181. flux_model_cfht-u    182. flux_model_hsc-g     183. flux_model_hsc-r     184. flux_model_hsc-i
# 185. flux_model_hsc-z     186. flux_model_hsc-y     187. flux_model_hsc-nb0816 188. flux_model_hsc-nb0921
# 189. flux_model_hsc-nb1010 190. flux_model_uvista-y  191. flux_model_uvista-j  192. flux_model_uvista-h
# 193. flux_model_uvista-ks 194. flux_model_uvista-nb118 195. flux_model_sc-ia484  196. flux_model_sc-ia527
# 197. flux_model_sc-ia624  198. flux_model_sc-ia679  199. flux_model_sc-ia738  200. flux_model_sc-ia767
# 201. flux_model_sc-ib427  202. flux_model_sc-ib505  203. flux_model_sc-ib574  204. flux_model_sc-ib709
# 205. flux_model_sc-ib827  206. flux_model_sc-nb711  207. flux_model_sc-nb816  208. flux_model_irac-ch1
# 209. flux_model_irac-ch2  210. flux_model_irac-ch3  211. flux_model_irac-ch4  212. flux_err-uncal_model_f115w
# 213. flux_err-uncal_model_f150w 214. flux_err-uncal_model_f277w 215. flux_err-uncal_model_f444w 216. flux_err-uncal_model_hst-f814w
# 217. flux_err-uncal_model_f770w 218. flux_err-uncal_model_cfht-u 219. flux_err-uncal_model_hsc-g 220. flux_err-uncal_model_hsc-r
# 221. flux_err-uncal_model_hsc-i 222. flux_err-uncal_model_hsc-z 223. flux_err-uncal_model_hsc-y 224. flux_err-uncal_model_hsc-nb0816
# 225. flux_err-uncal_model_hsc-nb0921 226. flux_err-uncal_model_hsc-nb1010 227. flux_err-uncal_model_uvista-y 228. flux_err-uncal_model_uvista-j
# 229. flux_err-uncal_model_uvista-h 230. flux_err-uncal_model_uvista-ks 231. flux_err-uncal_model_uvista-nb118 232. flux_err-uncal_model_sc-ia484
# 233. flux_err-uncal_model_sc-ia527 234. flux_err-uncal_model_sc-ia624 235. flux_err-uncal_model_sc-ia679 236. flux_err-uncal_model_sc-ia738
# 237. flux_err-uncal_model_sc-ia767 238. flux_err-uncal_model_sc-ib427 239. flux_err-uncal_model_sc-ib505 240. flux_err-uncal_model_sc-ib574
# 241. flux_err-uncal_model_sc-ib709 242. flux_err-uncal_model_sc-ib827 243. flux_err-uncal_model_sc-nb711 244. flux_err-uncal_model_sc-nb816
# 245. flux_err-uncal_model_irac-ch1 246. flux_err-uncal_model_irac-ch2 247. flux_err-uncal_model_irac-ch3 248. flux_err-uncal_model_irac-ch4
# 249. flag_star_hsc        250. flux_err-cal_model_f115w 251. flux_err-cal_model_f150w 252. flux_err-cal_model_f277w
# 253. flux_err-cal_model_f444w 254. flux_err-cal_model_hst-f814w 255. flux_err-cal_model_f770w 256. flux_err-cal_model_cfht-u
# 257. flux_err-cal_model_hsc-g 258. flux_err-cal_model_hsc-r 259. flux_err-cal_model_hsc-i 260. flux_err-cal_model_hsc-z
# 261. flux_err-cal_model_hsc-y 262. flux_err-cal_model_hsc-nb0816 263. flux_err-cal_model_hsc-nb0921 264. flux_err-cal_model_hsc-nb1010
# 265. flux_err-cal_model_uvista-y 266. flux_err-cal_model_uvista-j 267. flux_err-cal_model_uvista-h 268. flux_err-cal_model_uvista-ks
# 269. flux_err-cal_model_uvista-nb118 270. flux_err-cal_model_sc-ia484 271. flux_err-cal_model_sc-ia527 272. flux_err-cal_model_sc-ia624
# 273. flux_err-cal_model_sc-ia679 274. flux_err-cal_model_sc-ia738 275. flux_err-cal_model_sc-ia767 276. flux_err-cal_model_sc-ib427
# 277. flux_err-cal_model_sc-ib505 278. flux_err-cal_model_sc-ib574 279. flux_err-cal_model_sc-ib709 280. flux_err-cal_model_sc-ib827
# 281. flux_err-cal_model_sc-nb711 282. flux_err-cal_model_sc-nb816 283. flux_err-cal_model_irac-ch1 284. flux_err-cal_model_irac-ch2
# 285. flux_err-cal_model_irac-ch3 286. flux_err-cal_model_irac-ch4 287. warn_flag            288. zfinal
# 289. type                 290. zpdf_med             291. zpdf_l68             292. zpdf_u68
# 293. zchi2                294. chi2_best            295. nbfilt               296. zp_agn
# 297. chi2_agn             298. mod_agn              299. mod_star             300. chi_star
# 301. mod_minchi2_phys     302. ebv_minchi2          303. law_minchi2          304. age_minchi2
# 305. mass_minchi2         306. sfr_minchi2          307. ssfr_minchi2         308. age_l68
# 309. age_med              310. age_u68              311. mass_l68             312. mass_med
# 313. mass_u68             314. sfr_l68              315. sfr_med              316. sfr_u68
# 317. ssfr_l68             318. ssfr_med             319. ssfr_u68             320. l_nuv
# 321. l_r                  322. l_k                  323. mabs_nuv             324. mabs_r
# 325. mabs_j               326. mabs_k               327. flag_chandra         328. zpdf_med_space
# 329. zpdf_l68_space       330. zpdf_u68_space       331. mag_aper_f115w_SE++APER 332. mag_aper_f150w_SE++APER
# 333. mag_aper_f277w_SE++APER 334. mag_aper_f444w_SE++APER 335. mag_aper_hst-f814w_SE++APER 336. mag_aper_f770w_SE++APER
# 337. mag_aper_cfht-u      338. mag_aper_hsc-g       339. mag_aper_hsc-r       340. mag_aper_hsc-i
# 341. mag_aper_hsc-z       342. mag_aper_hsc-y       343. mag_aper_hsc-nb0816  344. mag_aper_hsc-nb0921
# 345. mag_aper_hsc-nb1010  346. mag_aper_uvista-y    347. mag_aper_uvista-j    348. mag_aper_uvista-h
# 349. mag_aper_uvista-ks   350. mag_aper_uvista-nb118 351. mag_aper_sc-ia484    352. mag_aper_sc-ia527
# 353. mag_aper_sc-ia624    354. mag_aper_sc-ia679    355. mag_aper_sc-ia738    356. mag_aper_sc-ia767
# 357. mag_aper_sc-ib427    358. mag_aper_sc-ib505    359. mag_aper_sc-ib574    360. mag_aper_sc-ib709
# 361. mag_aper_sc-ib827    362. mag_aper_sc-nb711    363. mag_aper_sc-nb816    364. mag_aper_irac-ch1
# 365. mag_aper_irac-ch2    366. mag_aper_irac-ch3    367. mag_aper_irac-ch4    368. mag_err_aper_f115w
# 369. mag_err_aper_f150w   370. mag_err_aper_f277w   371. mag_err_aper_f444w   372. mag_err_aper_hst-f814w
# 373. mag_err_aper_f770w   374. mag_err_aper_cfht-u  375. mag_err_aper_hsc-g   376. mag_err_aper_hsc-r
# 377. mag_err_aper_hsc-i   378. mag_err_aper_hsc-z   379. mag_err_aper_hsc-y   380. mag_err_aper_hsc-nb0816
# 381. mag_err_aper_hsc-nb0921 382. mag_err_aper_hsc-nb1010 383. mag_err_aper_uvista-y 384. mag_err_aper_uvista-j
# 385. mag_err_aper_uvista-h 386. mag_err_aper_uvista-ks 387. mag_err_aper_uvista-nb118 388. mag_err_aper_sc-ia484
# 389. mag_err_aper_sc-ia527 390. mag_err_aper_sc-ia624 391. mag_err_aper_sc-ia679 392. mag_err_aper_sc-ia738
# 393. mag_err_aper_sc-ia767 394. mag_err_aper_sc-ib427 395. mag_err_aper_sc-ib505 396. mag_err_aper_sc-ib574
# 397. mag_err_aper_sc-ib709 398. mag_err_aper_sc-ib827 399. mag_err_aper_sc-nb711 400. mag_err_aper_sc-nb816
# 401. mag_err_aper_irac-ch1 402. mag_err_aper_irac-ch2 403. mag_err_aper_irac-ch3 404. mag_err_aper_irac-ch4
# 405. flux_aper_f115w_SE++APER 406. flux_aper_f150w_SE++APER 407. flux_aper_f277w_SE++APER 408. flux_aper_f444w_SE++APER
# 409. flux_aper_hst-f814w_SE++APER 410. flux_aper_f770w_SE++APER 411. flux_aper_cfht-u     412. flux_aper_hsc-g
# 413. flux_aper_hsc-r      414. flux_aper_hsc-i      415. flux_aper_hsc-z      416. flux_aper_hsc-y
# 417. flux_aper_hsc-nb0816 418. flux_aper_hsc-nb0921 419. flux_aper_hsc-nb1010 420. flux_aper_uvista-y
# 421. flux_aper_uvista-j   422. flux_aper_uvista-h   423. flux_aper_uvista-ks  424. flux_aper_uvista-nb118
# 425. flux_aper_sc-ia484   426. flux_aper_sc-ia527   427. flux_aper_sc-ia624   428. flux_aper_sc-ia679
# 429. flux_aper_sc-ia738   430. flux_aper_sc-ia767   431. flux_aper_sc-ib427   432. flux_aper_sc-ib505
# 433. flux_aper_sc-ib574   434. flux_aper_sc-ib709   435. flux_aper_sc-ib827   436. flux_aper_sc-nb711
# 437. flux_aper_sc-nb816   438. flux_aper_irac-ch1   439. flux_aper_irac-ch2   440. flux_aper_irac-ch3
# 441. flux_aper_irac-ch4   442. flux_err_aper_f115w_SE++APER 443. flux_err_aper_f150w_SE++APER 444. flux_err_aper_f277w_SE++APER
# 445. flux_err_aper_f444w_SE++APER 446. flux_err_aper_hst-f814w_SE++APER 447. flux_err_aper_f770w_SE++APER 448. flux_err_aper_cfht-u
# 449. flux_err_aper_hsc-g  450. flux_err_aper_hsc-r  451. flux_err_aper_hsc-i  452. flux_err_aper_hsc-z
# 453. flux_err_aper_hsc-y  454. flux_err_aper_hsc-nb0816 455. flux_err_aper_hsc-nb0921 456. flux_err_aper_hsc-nb1010
# 457. flux_err_aper_uvista-y 458. flux_err_aper_uvista-j 459. flux_err_aper_uvista-h 460. flux_err_aper_uvista-ks
# 461. flux_err_aper_uvista-nb118 462. flux_err_aper_sc-ia484 463. flux_err_aper_sc-ia527 464. flux_err_aper_sc-ia624
# 465. flux_err_aper_sc-ia679 466. flux_err_aper_sc-ia738 467. flux_err_aper_sc-ia767 468. flux_err_aper_sc-ib427
# 469. flux_err_aper_sc-ib505 470. flux_err_aper_sc-ib574 471. flux_err_aper_sc-ib709 472. flux_err_aper_sc-ib827
# 473. flux_err_aper_sc-nb711 474. flux_err_aper_sc-nb816 475. flux_err_aper_irac-ch1 476. flux_err_aper_irac-ch2
# 477. flux_err_aper_irac-ch3 478. flux_err_aper_irac-ch4 479. age_form             480. age_form_err
# 481. sfr_mass_vector_dir  482. sfr_mass_vector_dir_err 483. sfh_sfr_bin1         484. sfh_sfr_bin1_err
# 485. sfh_sfr_bin2         486. sfh_sfr_bin2_err     487. sfh_sfr_bin3         488. sfh_sfr_bin3_err
# 489. sfh_sfr_bin4         490. sfh_sfr_bin4_err     491. sfh_sfr_bin5         492. sfh_sfr_bin5_err
# 493. sfh_sfr_bin6         494. sfh_sfr_bin6_err     495. sfh_sfr_bin7         496. sfh_sfr_bin7_err
# 497. sfh_sfr_bin8         498. sfh_sfr_bin8_err     499. sfh_sfr_bin9         500. sfh_sfr_bin9_err
# 501. sfr_mass_vector_norm 502. sfr_mass_vector_norm_err 503. sfh_time_bin1        504. sfh_time_bin1_err
# 505. sfh_time_bin2        506. sfh_time_bin2_err    507. sfh_time_bin3        508. sfh_time_bin3_err
# 509. sfh_time_bin4        510. sfh_time_bin4_err    511. sfh_time_bin5        512. sfh_time_bin5_err
# 513. sfh_time_bin6        514. sfh_time_bin6_err    515. sfh_time_bin7        516. sfh_time_bin7_err
# 517. sfh_time_bin8        518. sfh_time_bin8_err    519. sfh_time_bin9        520. sfh_time_bin9_err
# 521. metallicity          522. metallicity_err      523. sfh_integrated       524. sfh_integrated_err
# 525. sfr_inst             526. sfr_inst_err         527. sfr_100myr           528. sfr_100myr_err
# 529. mass                 530. mass_err             531. chi2_best_fit        532. chi2_red_best_fit
# 533. sph_0_f150w          534. disk_0_f150w         535. irr_0_f150w          536. bd_0_f150w
# 537. sph_1_f150w          538. disk_1_f150w         539. irr_1_f150w          540. bd_1_f150w
# 541. sph_2_f150w          542. disk_2_f150w         543. irr_2_f150w          544. bd_2_f150w
# 545. sph_3_f150w          546. disk_3_f150w         547. irr_3_f150w          548. bd_3_f150w
# 549. sph_4_f150w          550. disk_4_f150w         551. irr_4_f150w          552. bd_4_f150w
# 553. sph_5_f150w          554. disk_5_f150w         555. irr_5_f150w          556. bd_5_f150w
# 557. sph_6_f150w          558. disk_6_f150w         559. irr_6_f150w          560. bd_6_f150w
# 561. sph_7_f150w          562. disk_7_f150w         563. irr_7_f150w          564. bd_7_f150w
# 565. sph_8_f150w          566. disk_8_f150w         567. irr_8_f150w          568. bd_8_f150w
# 569. sph_9_f150w          570. disk_9_f150w         571. irr_9_f150w          572. bd_9_f150w
# 573. sph_0_f277w          574. disk_0_f277w         575. irr_0_f277w          576. bd_0_f277w
# 577. sph_1_f277w          578. disk_1_f277w         579. irr_1_f277w          580. bd_1_f277w
# 581. sph_2_f277w          582. disk_2_f277w         583. irr_2_f277w          584. bd_2_f277w
# 585. sph_3_f277w          586. disk_3_f277w         587. irr_3_f277w          588. bd_3_f277w
# 589. sph_4_f277w          590. disk_4_f277w         591. irr_4_f277w          592. bd_4_f277w
# 593. sph_5_f277w          594. disk_5_f277w         595. irr_5_f277w          596. bd_5_f277w
# 597. sph_6_f277w          598. disk_6_f277w         599. irr_6_f277w          600. bd_6_f277w
# 601. sph_7_f277w          602. disk_7_f277w         603. irr_7_f277w          604. bd_7_f277w
# 605. sph_8_f277w          606. disk_8_f277w         607. irr_8_f277w          608. bd_8_f277w
# 609. sph_9_f277w          610. disk_9_f277w         611. irr_9_f277w          612. bd_9_f277w
# 613. sph_0_f444w          614. disk_0_f444w         615. irr_0_f444w          616. bd_0_f444w
# 617. sph_1_f444w          618. disk_1_f444w         619. irr_1_f444w          620. bd_1_f444w
# 621. sph_2_f444w          622. disk_2_f444w         623. irr_2_f444w          624. bd_2_f444w
# 625. sph_3_f444w          626. disk_3_f444w         627. irr_3_f444w          628. bd_3_f444w
# 629. sph_4_f444w          630. disk_4_f444w         631. irr_4_f444w          632. bd_4_f444w
# 633. sph_5_f444w          634. disk_5_f444w         635. irr_5_f444w          636. bd_5_f444w
# 637. sph_6_f444w          638. disk_6_f444w         639. irr_6_f444w          640. bd_6_f444w
# 641. sph_7_f444w          642. disk_7_f444w         643. irr_7_f444w          644. bd_7_f444w
# 645. sph_8_f444w          646. disk_8_f444w         647. irr_8_f444w          648. bd_8_f444w
# 649. sph_9_f444w          650. disk_9_f444w         651. irr_9_f444w          652. bd_9_f444w
# 653. sph_f150w_mean       654. sph_f150w_std        655. disk_f150w_mean      656. disk_f150w_std
# 657. irr_f150w_mean       658. irr_f150w_std        659. bd_f150w_mean        660. bd_f150w_std
# 661. sph_f277w_mean       662. sph_f277w_std        663. disk_f277w_mean      664. disk_f277w_std
# 665. irr_f277w_mean       666. irr_f277w_std        667. bd_f277w_mean        668. bd_f277w_std
# 669. sph_f444w_mean       670. sph_f444w_std        671. disk_f444w_mean      672. disk_f444w_std
# 673. irr_f444w_mean       674. irr_f444w_std        675. bd_f444w_mean        676. bd_f444w_std
# 677. morph_flag_f277w     678. delta_f277w          679. morph_flag_f444w     680. delta_f444w
# 681. morph_flag_f150w     682. delta_f150w          683. ra_detec_bd          684. dec_detec_bd
# 685. disk_radius_deg      686. disk_radius_deg_err  687. bulge_radius_deg     688. bulge_radius_deg_err
# 689. angle_bd             690. angle_bd_err         691. disk_axratio         692. disk_axratio_err
# 693. bulge_axratio        694. bulge_axratio_err    695. fmf_b+d_chi2         696. mag_model_bd_total_f115w
# 697. mag_model_bd_total_f150w 698. mag_model_bd_total_f277w 699. mag_model_bd_total_f444w 700. mag_err_model_bd_total_f115w
# 701. mag_err_model_bd_total_f150w 702. mag_err_model_bd_total_f277w 703. mag_err_model_bd_total_f444w 704. mag_model_bulge_f115w
# 705. mag_model_bulge_f150w 706. mag_model_bulge_f277w 707. mag_model_bulge_f444w 708. mag_err_model_bulge_f115w
# 709. mag_err_model_bulge_f150w 710. mag_err_model_bulge_f277w 711. mag_err_model_bulge_f444w 712. mag_model_disk_f115w
# 713. mag_model_disk_f150w 714. mag_model_disk_f277w 715. mag_model_disk_f444w 716. mag_err_model_disk_f115w
# 717. mag_err_model_disk_f150w 718. mag_err_model_disk_f277w 719. mag_err_model_disk_f444w 720. flux_model_bd_total_f115w
# 721. flux_model_bd_total_f150w 722. flux_model_bd_total_f277w 723. flux_model_bd_total_f444w 724. flux_err_model_bd_total_f115w
# 725. flux_err_model_bd_total_f150w 726. flux_err_model_bd_total_f277w 727. flux_err_model_bd_total_f444w 728. flux_model_bulge_f115w
# 729. flux_model_bulge_f150w 730. flux_model_bulge_f277w 731. flux_model_bulge_f444w 732. flux_err_model_bulge_f115w
# 733. flux_err_model_bulge_f150w 734. flux_err_model_bulge_f277w 735. flux_err_model_bulge_f444w 736. flux_model_disk_f115w
# 737. flux_model_disk_f150w 738. flux_model_disk_f277w 739. flux_model_disk_f444w 740. flux_err_model_disk_f115w
# 741. flux_err_model_disk_f150w 742. flux_err_model_disk_f277w 743. flux_err_model_disk_f444w 744. b/t_f115w
# 745. b/t_f150w            746. b/t_f277w            747. b/t_f444w            748. b/t_err_f115w
# 749. b/t_err_f150w        750. b/t_err_f277w        751. b/t_err_f444w        752. mag_model_bd_total_hst-f814w
# 753. mag_model_bd_total_f770w 754. mag_model_bd_total_cfht-u 755. mag_model_bd_total_hsc-g 756. mag_model_bd_total_hsc-r
# 757. mag_model_bd_total_hsc-i 758. mag_model_bd_total_hsc-z 759. mag_model_bd_total_hsc-y 760. mag_model_bd_total_hsc-nb0816
# 761. mag_model_bd_total_hsc-nb0921 762. mag_model_bd_total_hsc-nb1010 763. mag_model_bd_total_uvista-y 764. mag_model_bd_total_uvista-j
# 765. mag_model_bd_total_uvista-h 766. mag_model_bd_total_uvista-ks 767. mag_model_bd_total_sc-ia484 768. mag_model_bd_total_sc-ia527
# 769. mag_model_bd_total_sc-ia624 770. mag_model_bd_total_sc-ia679 771. mag_model_bd_total_sc-ia738 772. mag_model_bd_total_sc-ia767
# 773. mag_model_bd_total_sc-ib427 774. mag_model_bd_total_sc-ib505 775. mag_model_bd_total_sc-ib574 776. mag_model_bd_total_sc-ib709
# 777. mag_model_bd_total_sc-ib827 778. mag_model_bd_total_sc-nb711 779. mag_model_bd_total_sc-nb816 780. mag_err_model_bd_total_hst-f814w
# 781. mag_err_model_bd_total_f770w 782. mag_err_model_bd_total_cfht-u 783. mag_err_model_bd_total_hsc-g 784. mag_err_model_bd_total_hsc-r
# 785. mag_err_model_bd_total_hsc-i 786. mag_err_model_bd_total_hsc-z 787. mag_err_model_bd_total_hsc-y 788. mag_err_model_bd_total_hsc-nb0816
# 789. mag_err_model_bd_total_hsc-nb0921 790. mag_err_model_bd_total_hsc-nb1010 791. mag_err_model_bd_total_uvista-y 792. mag_err_model_bd_total_uvista-j
# 793. mag_err_model_bd_total_uvista-h 794. mag_err_model_bd_total_uvista-ks 795. mag_err_model_bd_total_sc-ia484 796. mag_err_model_bd_total_sc-ia527
# 797. mag_err_model_bd_total_sc-ia624 798. mag_err_model_bd_total_sc-ia679 799. mag_err_model_bd_total_sc-ia738 800. mag_err_model_bd_total_sc-ia767
# 801. mag_err_model_bd_total_sc-ib427 802. mag_err_model_bd_total_sc-ib505 803. mag_err_model_bd_total_sc-ib574 804. mag_err_model_bd_total_sc-ib709
# 805. mag_err_model_bd_total_sc-ib827 806. mag_err_model_bd_total_sc-nb711 807. mag_err_model_bd_total_sc-nb816 808. mag_model_bulge_hst-f814w
# 809. mag_model_bulge_f770w 810. mag_model_bulge_cfht-u 811. mag_model_bulge_hsc-g 812. mag_model_bulge_hsc-r
# 813. mag_model_bulge_hsc-i 814. mag_model_bulge_hsc-z 815. mag_model_bulge_hsc-y 816. mag_model_bulge_hsc-nb0816
# 817. mag_model_bulge_hsc-nb0921 818. mag_model_bulge_hsc-nb1010 819. mag_model_bulge_uvista-y 820. mag_model_bulge_uvista-j
# 821. mag_model_bulge_uvista-h 822. mag_model_bulge_uvista-ks 823. mag_model_bulge_sc-ia484 824. mag_model_bulge_sc-ia527
# 825. mag_model_bulge_sc-ia624 826. mag_model_bulge_sc-ia679 827. mag_model_bulge_sc-ia738 828. mag_model_bulge_sc-ia767
# 829. mag_model_bulge_sc-ib427 830. mag_model_bulge_sc-ib505 831. mag_model_bulge_sc-ib574 832. mag_model_bulge_sc-ib709
# 833. mag_model_bulge_sc-ib827 834. mag_model_bulge_sc-nb711 835. mag_model_bulge_sc-nb816 836. mag_err_model_bulge_hst-f814w
# 837. mag_err_model_bulge_f770w 838. mag_err_model_bulge_cfht-u 839. mag_err_model_bulge_hsc-g 840. mag_err_model_bulge_hsc-r
# 841. mag_err_model_bulge_hsc-i 842. mag_err_model_bulge_hsc-z 843. mag_err_model_bulge_hsc-y 844. mag_err_model_bulge_hsc-nb0816
# 845. mag_err_model_bulge_hsc-nb0921 846. mag_err_model_bulge_hsc-nb1010 847. mag_err_model_bulge_uvista-y 848. mag_err_model_bulge_uvista-j
# 849. mag_err_model_bulge_uvista-h 850. mag_err_model_bulge_uvista-ks 851. mag_err_model_bulge_sc-ia484 852. mag_err_model_bulge_sc-ia527
# 853. mag_err_model_bulge_sc-ia624 854. mag_err_model_bulge_sc-ia679 855. mag_err_model_bulge_sc-ia738 856. mag_err_model_bulge_sc-ia767
# 857. mag_err_model_bulge_sc-ib427 858. mag_err_model_bulge_sc-ib505 859. mag_err_model_bulge_sc-ib574 860. mag_err_model_bulge_sc-ib709
# 861. mag_err_model_bulge_sc-ib827 862. mag_err_model_bulge_sc-nb711 863. mag_err_model_bulge_sc-nb816 864. mag_model_disk_hst-f814w
# 865. mag_model_disk_f770w 866. mag_model_disk_cfht-u 867. mag_model_disk_hsc-g 868. mag_model_disk_hsc-r
# 869. mag_model_disk_hsc-i 870. mag_model_disk_hsc-z 871. mag_model_disk_hsc-y 872. mag_model_disk_hsc-nb0816
# 873. mag_model_disk_hsc-nb0921 874. mag_model_disk_hsc-nb1010 875. mag_model_disk_uvista-y 876. mag_model_disk_uvista-j
# 877. mag_model_disk_uvista-h 878. mag_model_disk_uvista-ks 879. mag_model_disk_sc-ia484 880. mag_model_disk_sc-ia527
# 881. mag_model_disk_sc-ia624 882. mag_model_disk_sc-ia679 883. mag_model_disk_sc-ia738 884. mag_model_disk_sc-ia767
# 885. mag_model_disk_sc-ib427 886. mag_model_disk_sc-ib505 887. mag_model_disk_sc-ib574 888. mag_model_disk_sc-ib709
# 889. mag_model_disk_sc-ib827 890. mag_model_disk_sc-nb711 891. mag_model_disk_sc-nb816 892. mag_err_model_disk_hst-f814w
# 893. mag_err_model_disk_f770w 894. mag_err_model_disk_cfht-u 895. mag_err_model_disk_hsc-g 896. mag_err_model_disk_hsc-r
# 897. mag_err_model_disk_hsc-i 898. mag_err_model_disk_hsc-z 899. mag_err_model_disk_hsc-y 900. mag_err_model_disk_hsc-nb0816
# 901. mag_err_model_disk_hsc-nb0921 902. mag_err_model_disk_hsc-nb1010 903. mag_err_model_disk_uvista-y 904. mag_err_model_disk_uvista-j
# 905. mag_err_model_disk_uvista-h 906. mag_err_model_disk_uvista-ks 907. mag_err_model_disk_sc-ia484 908. mag_err_model_disk_sc-ia527
# 909. mag_err_model_disk_sc-ia624 910. mag_err_model_disk_sc-ia679 911. mag_err_model_disk_sc-ia738 912. mag_err_model_disk_sc-ia767
# 913. mag_err_model_disk_sc-ib427 914. mag_err_model_disk_sc-ib505 915. mag_err_model_disk_sc-ib574 916. mag_err_model_disk_sc-ib709
# 917. mag_err_model_disk_sc-ib827 918. mag_err_model_disk_sc-nb711 919. mag_err_model_disk_sc-nb816 920. flux_model_bd_total_hst-f814w
# 921. flux_model_bd_total_f770w 922. flux_model_bd_total_cfht-u 923. flux_model_bd_total_hsc-g 924. flux_model_bd_total_hsc-r
# 925. flux_model_bd_total_hsc-i 926. flux_model_bd_total_hsc-z 927. flux_model_bd_total_hsc-y 928. flux_model_bd_total_hsc-nb0816
# 929. flux_model_bd_total_hsc-nb0921 930. flux_model_bd_total_hsc-nb1010 931. flux_model_bd_total_uvista-y 932. flux_model_bd_total_uvista-j
# 933. flux_model_bd_total_uvista-h 934. flux_model_bd_total_uvista-ks 935. flux_model_bd_total_sc-ia484 936. flux_model_bd_total_sc-ia527
# 937. flux_model_bd_total_sc-ia624 938. flux_model_bd_total_sc-ia679 939. flux_model_bd_total_sc-ia738 940. flux_model_bd_total_sc-ia767
# 941. flux_model_bd_total_sc-ib427 942. flux_model_bd_total_sc-ib505 943. flux_model_bd_total_sc-ib574 944. flux_model_bd_total_sc-ib709
# 945. flux_model_bd_total_sc-ib827 946. flux_model_bd_total_sc-nb711 947. flux_model_bd_total_sc-nb816 948. flux_err_model_bd_total_hst-f814w
# 949. flux_err_model_bd_total_f770w 950. flux_err_model_bd_total_cfht-u 951. flux_err_model_bd_total_hsc-g 952. flux_err_model_bd_total_hsc-r
# 953. flux_err_model_bd_total_hsc-i 954. flux_err_model_bd_total_hsc-z 955. flux_err_model_bd_total_hsc-y 956. flux_err_model_bd_total_hsc-nb0816
# 957. flux_err_model_bd_total_hsc-nb0921 958. flux_err_model_bd_total_hsc-nb1010 959. flux_err_model_bd_total_uvista-y 960. flux_err_model_bd_total_uvista-j
# 961. flux_err_model_bd_total_uvista-h 962. flux_err_model_bd_total_uvista-ks 963. flux_err_model_bd_total_sc-ia484 964. flux_err_model_bd_total_sc-ia527
# 965. flux_err_model_bd_total_sc-ia624 966. flux_err_model_bd_total_sc-ia679 967. flux_err_model_bd_total_sc-ia738 968. flux_err_model_bd_total_sc-ia767
# 969. flux_err_model_bd_total_sc-ib427 970. flux_err_model_bd_total_sc-ib505 971. flux_err_model_bd_total_sc-ib574 972. flux_err_model_bd_total_sc-ib709
# 973. flux_err_model_bd_total_sc-ib827 974. flux_err_model_bd_total_sc-nb711 975. flux_err_model_bd_total_sc-nb816 976. flux_model_bulge_hst-f814w
# 977. flux_model_bulge_f770w 978. flux_model_bulge_cfht-u 979. flux_model_bulge_hsc-g 980. flux_model_bulge_hsc-r
# 981. flux_model_bulge_hsc-i 982. flux_model_bulge_hsc-z 983. flux_model_bulge_hsc-y 984. flux_model_bulge_hsc-nb0816
# 985. flux_model_bulge_hsc-nb0921 986. flux_model_bulge_hsc-nb1010 987. flux_model_bulge_uvista-y 988. flux_model_bulge_uvista-j
# 989. flux_model_bulge_uvista-h 990. flux_model_bulge_uvista-ks 991. flux_model_bulge_sc-ia484 992. flux_model_bulge_sc-ia527
# 993. flux_model_bulge_sc-ia624 994. flux_model_bulge_sc-ia679 995. flux_model_bulge_sc-ia738 996. flux_model_bulge_sc-ia767
# 997. flux_model_bulge_sc-ib427 998. flux_model_bulge_sc-ib505 999. flux_model_bulge_sc-ib574 1000. flux_model_bulge_sc-ib709
# 1001. flux_model_bulge_sc-ib827 1002. flux_model_bulge_sc-nb711 1003. flux_model_bulge_sc-nb816 1004. flux_err_model_bulge_hst-f814w
# 1005. flux_err_model_bulge_f770w 1006. flux_err_model_bulge_cfht-u 1007. flux_err_model_bulge_hsc-g 1008. flux_err_model_bulge_hsc-r
# 1009. flux_err_model_bulge_hsc-i 1010. flux_err_model_bulge_hsc-z 1011. flux_err_model_bulge_hsc-y 1012. flux_err_model_bulge_hsc-nb0816
# 1013. flux_err_model_bulge_hsc-nb0921 1014. flux_err_model_bulge_hsc-nb1010 1015. flux_err_model_bulge_uvista-y 1016. flux_err_model_bulge_uvista-j
# 1017. flux_err_model_bulge_uvista-h 1018. flux_err_model_bulge_uvista-ks 1019. flux_err_model_bulge_sc-ia484 1020. flux_err_model_bulge_sc-ia527
# 1021. flux_err_model_bulge_sc-ia624 1022. flux_err_model_bulge_sc-ia679 1023. flux_err_model_bulge_sc-ia738 1024. flux_err_model_bulge_sc-ia767
# 1025. flux_err_model_bulge_sc-ib427 1026. flux_err_model_bulge_sc-ib505 1027. flux_err_model_bulge_sc-ib574 1028. flux_err_model_bulge_sc-ib709
# 1029. flux_err_model_bulge_sc-ib827 1030. flux_err_model_bulge_sc-nb711 1031. flux_err_model_bulge_sc-nb816 1032. flux_model_disk_hst-f814w
# 1033. flux_model_disk_f770w 1034. flux_model_disk_cfht-u 1035. flux_model_disk_hsc-g 1036. flux_model_disk_hsc-r
# 1037. flux_model_disk_hsc-i 1038. flux_model_disk_hsc-z 1039. flux_model_disk_hsc-y 1040. flux_model_disk_hsc-nb0816
# 1041. flux_model_disk_hsc-nb0921 1042. flux_model_disk_hsc-nb1010 1043. flux_model_disk_uvista-y 1044. flux_model_disk_uvista-j
# 1045. flux_model_disk_uvista-h 1046. flux_model_disk_uvista-ks 1047. flux_model_disk_sc-ia484 1048. flux_model_disk_sc-ia527
# 1049. flux_model_disk_sc-ia624 1050. flux_model_disk_sc-ia679 1051. flux_model_disk_sc-ia738 1052. flux_model_disk_sc-ia767
# 1053. flux_model_disk_sc-ib427 1054. flux_model_disk_sc-ib505 1055. flux_model_disk_sc-ib574 1056. flux_model_disk_sc-ib709
# 1057. flux_model_disk_sc-ib827 1058. flux_model_disk_sc-nb711 1059. flux_model_disk_sc-nb816 1060. flux_err_model_disk_hst-f814w
# 1061. flux_err_model_disk_f770w 1062. flux_err_model_disk_cfht-u 1063. flux_err_model_disk_hsc-g 1064. flux_err_model_disk_hsc-r
# 1065. flux_err_model_disk_hsc-i 1066. flux_err_model_disk_hsc-z 1067. flux_err_model_disk_hsc-y 1068. flux_err_model_disk_hsc-nb0816
# 1069. flux_err_model_disk_hsc-nb0921 1070. flux_err_model_disk_hsc-nb1010 1071. flux_err_model_disk_uvista-y 1072. flux_err_model_disk_uvista-j
# 1073. flux_err_model_disk_uvista-h 1074. flux_err_model_disk_uvista-ks 1075. flux_err_model_disk_sc-ia484 1076. flux_err_model_disk_sc-ia527
# 1077. flux_err_model_disk_sc-ia624 1078. flux_err_model_disk_sc-ia679 1079. flux_err_model_disk_sc-ia738 1080. flux_err_model_disk_sc-ia767
# 1081. flux_err_model_disk_sc-ib427 1082. flux_err_model_disk_sc-ib505 1083. flux_err_model_disk_sc-ib574 1084. flux_err_model_disk_sc-ib709
# 1085. flux_err_model_disk_sc-ib827 1086. flux_err_model_disk_sc-nb711 1087. flux_err_model_disk_sc-nb816 1088. b/t_hst-f814w
# 1089. b/t_f770w            1090. b/t_cfht-u           1091. b/t_hsc-g            1092. b/t_hsc-r
# 1093. b/t_hsc-i            1094. b/t_hsc-z            1095. b/t_hsc-y            1096. b/t_hsc-nb0816
# 1097. b/t_hsc-nb0921       1098. b/t_hsc-nb1010       1099. b/t_uvista-y         1100. b/t_uvista-j
# 1101. b/t_uvista-h         1102. b/t_uvista-ks        1103. b/t_sc-ia484         1104. b/t_sc-ia527
# 1105. b/t_sc-ia624         1106. b/t_sc-ia679         1107. b/t_sc-ia738         1108. b/t_sc-ia767
# 1109. b/t_sc-ib427         1110. b/t_sc-ib505         1111. b/t_sc-ib574         1112. b/t_sc-ib709
# 1113. b/t_sc-ib827         1114. b/t_sc-nb711         1115. b/t_sc-nb816         1116. b/t_err_hst-f814w
# 1117. b/t_err_f770w        1118. b/t_err_cfht-u       1119. b/t_err_hsc-g        1120. b/t_err_hsc-r
# 1121. b/t_err_hsc-i        1122. b/t_err_hsc-z        1123. b/t_err_hsc-y        1124. b/t_err_hsc-nb0816
# 1125. b/t_err_hsc-nb0921   1126. b/t_err_hsc-nb1010   1127. b/t_err_uvista-y     1128. b/t_err_uvista-j
# 1129. b/t_err_uvista-h     1130. b/t_err_uvista-ks    1131. b/t_err_sc-ia484     1132. b/t_err_sc-ia527
# 1133. b/t_err_sc-ia624     1134. b/t_err_sc-ia679     1135. b/t_err_sc-ia738     1136. b/t_err_sc-ia767
# 1137. b/t_err_sc-ib427     1138. b/t_err_sc-ib505     1139. b/t_err_sc-ib574     1140. b/t_err_sc-ib709
# 1141. b/t_err_sc-ib827     1142. b/t_err_sc-nb711     1143. b/t_err_sc-nb816
#
# ================================================================================
#
# === Searching for Key Columns ===
# COORDINATES    : radius_sersic_err, mag_err_aper_irac-ch3, disk_axratio_err, mag_aper_irac-ch2, mag_err_aper_irac-ch4, flux_err-uncal_model_irac-ch4, flux_err_aper_irac-ch2, dec_model, flux_err-uncal_model_irac-ch3, axratio_sersic, sfh_integrated_err, flag_chandra, bulge_radius_deg_err, mag_err_model_irac-ch4, bulge_axratio_err, mag_err_aper_irac-ch1, ra, delta_f150w, flux_aper_irac-ch3, flux_model_irac-ch1, dec_detec_bd, bulge_radius_deg, mag_aper_irac-ch1, delta_f277w, mag_model_irac-ch1, flux_err-cal_model_irac-ch4, flux_model_irac-ch4, mag_aper_irac-ch4, mag_err_model_irac-ch2, kron_rad, flux_err-uncal_model_irac-ch2, flux_err-cal_model_irac-ch1, flux_err_aper_irac-ch1, flux_err_aper_irac-ch3, ra_model, mag_err_aper_irac-ch2, disk_radius_deg_err, mag_model_irac-ch3, disk_axratio, mag_err_model_irac-ch1, flux_aper_irac-ch4, flux_err-cal_model_irac-ch2, flux_aper_irac-ch2, mag_err_model_irac-ch3, mag_model_irac-ch4, mag_model_irac-ch2, disk_radius_deg, axratio_sersic_err, flux_err-cal_model_irac-ch3, mag_aper_irac-ch3, bulge_axratio, delta_f444w, sfh_integrated, flux_err_aper_irac-ch4, dec, flux_model_irac-ch2, ra_detec_bd, flux_err-uncal_model_irac-ch1, radius_sersic, flux_aper_irac-ch1, flux_model_irac-ch3
# REDSHIFT       : zpdf_u68, zp_agn, mag_model_bd_total_hsc-z, zpdf_l68_space, flux_model_disk_hsc-z, zpdf_u68_space, flux_aper_hsc-z, zpdf_med, mag_err_model_hsc-z, flux_model_hsc-z, flux_err_model_bulge_hsc-z, b/t_hsc-z, mag_aper_hsc-z, flux_model_bd_total_hsc-z, zpdf_med_space, id_specz_khostovan25, flux_err_model_disk_hsc-z, flux_model_bulge_hsc-z, mag_model_hsc-z, zpdf_l68, flux_err-cal_model_hsc-z, zchi2, mag_err_model_bd_total_hsc-z, mag_err_model_disk_hsc-z, mag_model_bulge_hsc-z, mag_err_model_bulge_hsc-z, b/t_err_hsc-z, zfinal, mag_err_aper_hsc-z, flux_err_model_bd_total_hsc-z, flux_err-uncal_model_hsc-z, flux_err_aper_hsc-z, mag_model_disk_hsc-z
# STELLAR_MASS   : mass_med, mass_minchi2, mass_err, sfr_mass_vector_dir_err, mass_u68, mass, mass_l68, sfr_mass_vector_norm, sfr_mass_vector_norm_err, sfr_mass_vector_dir
# SFR            : ssfr_minchi2, sfh_sfr_bin2_err, sfh_sfr_bin6, sfr_inst_err, sfr_u68, sfh_sfr_bin7, sfh_sfr_bin3_err, sfh_sfr_bin1, ssfr_u68, sfr_inst, sfh_sfr_bin1_err, sfh_sfr_bin7_err, ssfr_l68, sfr_mass_vector_dir_err, sfr_mass_vector_dir, sfh_sfr_bin5, ssfr_med, sfr_med, sfh_sfr_bin3, sfr_minchi2, sfh_sfr_bin4_err, sfh_sfr_bin6_err, sfh_sfr_bin2, sfh_sfr_bin8, sfh_sfr_bin5_err, sfr_mass_vector_norm_err, sfh_sfr_bin4, sfh_sfr_bin9_err, sfr_100myr_err, sfr_100myr, sfh_sfr_bin8_err, sfr_l68, sfh_sfr_bin9, sfr_mass_vector_norm
# SIZE           : radius_sersic_err, seg_area, disk_radius_deg_err, kron2_area, bulge_radius_deg, chi2_red_best_fit, kron1_area, radius_sersic, disk_radius_deg, bulge_radius_deg_err
# MORPHOLOGY     : warn_flag, morph_flag_f150w, flag_blend, flag_star_hsc, morph_flag_f277w, flag_chandra, flag_star, type, morph_flag_f444w

# %%
# Define column mapping across multiple catalogs
# UPDATE THESE BASED ON THE OUTPUT OF THE PREVIOUS CELL
column_mapping = {
    # Format: 'parameter': ('catalog_name', 'column_name')
    'id': ('PHOTOMETRY HOTCOLD AND SE++', 'id'),
    'ra': ('PHOTOMETRY HOTCOLD AND SE++', 'ra'),
    'dec': ('PHOTOMETRY HOTCOLD AND SE++', 'dec'),  
    'redshift': ('LEPHARE', 'zfinal'),
    'stellar_mass': ('CIGALE', 'mass'),
    'sfr': ('CIGALE', 'sfr_inst'),
    'size': ('PHOTOMETRY HOTCOLD AND SE++', 'radius_sersic'),  # Effective radius of the Sersic model [deg]
}

print("MANUAL UPDATE REQUIRED:")
print("Update the column_mapping dictionary above based on the previous cell output.")
print("Format: 'parameter': ('catalog_name', 'column_name')")
print("\\nExample:")
print("column_mapping = {")
print("    'id': ('HDU_1', 'ID'),")
print("    'ra': ('HDU_1', 'RA'),")
print("    'dec': ('HDU_1', 'DEC'),") 
print("    'redshift': ('photometry_cat', 'z_phot'),")
print("    'stellar_mass': ('derived_props', 'logmass'),")
print("    'sfr': ('derived_props', 'SFR'),")
print("    'size': ('morphology', 're_arcsec'),")
print("}")

def create_unified_catalog(all_cats, col_map):
    """
    Create a unified catalog by extracting specified columns from different catalogs
    """
    print("=== Creating Unified Catalog ===")
    
    # Check if all required catalogs and columns exist
    missing_items = []
    for param, (cat_name, col_name) in col_map.items():
        if cat_name is None or col_name is None:
            missing_items.append(f"{param}: ({cat_name}, {col_name})")
            continue
            
        if cat_name not in all_cats:
            missing_items.append(f"Catalog '{cat_name}' not found for {param}")
            continue
            
        if col_name not in all_cats[cat_name].colnames:
            missing_items.append(f"Column '{col_name}' not found in {cat_name} for {param}")
            continue
    
    if missing_items:
        print("ERROR: Missing items in column mapping:")
        for item in missing_items:
            print(f"  - {item}")
        print("Please update column_mapping first!")
        return None
    
    # Get the primary catalog (usually contains ID and coordinates)
    primary_info = col_map['id']
    primary_cat_name = primary_info[0]
    primary_table = all_cats[primary_cat_name]
    id_col = primary_info[1]
    
    print(f"Using '{primary_cat_name}' as primary catalog ({len(primary_table)} objects)")
    
    # Start with the primary catalog's ID column
    unified_data = {
        'id': primary_table[id_col],
    }
    
    # Extract columns from each catalog
    for param, (cat_name, col_name) in col_map.items():
        if param == 'id':
            continue  # Already added
            
        source_table = all_cats[cat_name]
        print(f"Adding {param} from {cat_name}.{col_name}")
        
        if cat_name == primary_cat_name:
            # Same catalog, direct assignment
            unified_data[param] = source_table[col_name]
        else:
            # Different catalog, need to match by ID
            # This assumes all catalogs have the same ID column
            source_id_col = col_map['id'][1]  # Use same ID column name
            
            if source_id_col in source_table.colnames:
                # Convert to pandas for easier merging
                primary_df = pd.DataFrame({'id': unified_data['id']})
                source_df = source_table[[source_id_col, col_name]].to_pandas()
                source_df = source_df.rename(columns={source_id_col: 'id'})
                
                # Merge
                merged = pd.merge(primary_df, source_df, on='id', how='left')
                unified_data[param] = merged[col_name].values
                
                n_matched = (~pd.isna(merged[col_name])).sum()
                print(f"  Matched {n_matched}/{len(primary_table)} objects ({n_matched/len(primary_table)*100:.1f}%)")
            else:
                print(f"  WARNING: ID column '{source_id_col}' not found in {cat_name}")
                # Fill with NaN
                unified_data[param] = np.full(len(primary_table), np.nan)
    
    # Create unified astropy Table
    unified_table = Table(unified_data)
    print(f"\\nUnified catalog created: {len(unified_table)} objects × {len(unified_table.colnames)} columns")
    
    return unified_table

# Create unified catalog (only if column_mapping is properly defined)
if all(v[0] is not None and v[1] is not None for v in column_mapping.values()):
    catalog = create_unified_catalog(all_catalogs, column_mapping)
else:
    print("Please update column_mapping first!")
    print("Available catalogs:", list(all_catalogs.keys()) if 'all_catalogs' in locals() else "None")
# Out:
# MANUAL UPDATE REQUIRED:
# Update the column_mapping dictionary above based on the previous cell output.
# Format: 'parameter': ('catalog_name', 'column_name')
# \nExample:
# column_mapping = {
#     'id': ('HDU_1', 'ID'),
#     'ra': ('HDU_1', 'RA'),
#     'dec': ('HDU_1', 'DEC'),
#     'redshift': ('photometry_cat', 'z_phot'),
#     'stellar_mass': ('derived_props', 'logmass'),
#     'sfr': ('derived_props', 'SFR'),
#     'size': ('morphology', 're_arcsec'),
# }
# === Creating Unified Catalog ===
# Using 'PHOTOMETRY HOTCOLD AND SE++' as primary catalog (784016 objects)
# Adding ra from PHOTOMETRY HOTCOLD AND SE++.ra
# Adding dec from PHOTOMETRY HOTCOLD AND SE++.dec
# Adding redshift from LEPHARE.zfinal
#   WARNING: ID column 'id' not found in LEPHARE
# Adding stellar_mass from CIGALE.mass
#   WARNING: ID column 'id' not found in CIGALE
# Adding sfr from CIGALE.sfr_inst
#   WARNING: ID column 'id' not found in CIGALE
# Adding size from PHOTOMETRY HOTCOLD AND SE++.radius_sersic
# \nUnified catalog created: 784016 objects × 7 columns

# %%
# Let's examine the first few rows and basic statistics
# Convert to pandas for easier manipulation (if not too large)
if len(catalog) < 1000000:  # Only convert if less than 1M objects
    df = catalog.to_pandas()
    print("Converted to pandas DataFrame")
    
    # Show basic info
    print(f"\n=== Basic Information ===")
    print(f"Shape: {df.shape}")
    print(f"Data types summary:")
    print(df.dtypes.value_counts())
    
    # Show first few rows of key columns if we found them
    display_cols = []
    for category, cols in found_cols.items():
        if cols:
            display_cols.extend(cols[:2])  # Take first 2 from each category
    
    if display_cols:
        print(f"\n=== Sample Data (first 5 rows) ===")
        available_cols = [col for col in display_cols[:10] if col in df.columns]
        if available_cols:
            print(df[available_cols].head())
    
else:
    print(f"Catalog too large ({len(catalog)} objects) - keeping as astropy Table")
    print("First 3 rows:")
    print(catalog[:3])
# Out:
# Converted to pandas DataFrame
#
# === Basic Information ===
# Shape: (784016, 7)
# Data types summary:
# float64    6
# int64      1
# Name: count, dtype: int64
#
# === Sample Data (first 5 rows) ===

# %%
print(df.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784016 entries, 0 to 784015
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            784016 non-null  int64
#  1   ra            784016 non-null  float64
#  2   dec           784016 non-null  float64
#  3   redshift      0 non-null       float64
#  4   stellar_mass  0 non-null       float64
#  5   sfr           0 non-null       float64
#  6   size          784016 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 41.9 MB
# None

# %% [markdown]
# ## 5. Define Selection Criteria and Apply Initial Filters

# %%
# Based on the column inspection above, define the actual column names to use
# UPDATE THESE BASED ON THE OUTPUT OF THE PREVIOUS CELLS
column_mapping = {
    'ra': 'ra',           # Replace with actual RA column name
    'dec': 'dec',          # Replace with actual DEC column name  
    'redshift': 'redshift',     # Replace with actual redshift column name
    'stellar_mass': 'stellar_mass', # Replace with actual stellar mass column name
    'sfr': 'sfr',          # Replace with actual SFR column name
    'size': 'size',         # Replace with actual size column name
}

print("MANUAL UPDATE REQUIRED:")
print("Please update the column_mapping dictionary above with the actual column names")
print("found in the previous cell output, then run the following cells.")
print("\nExample:")
print("column_mapping = {")
print("    'ra': 'RA_1',")
print("    'dec': 'DEC_1',")
print("    'redshift': 'z_phot',")
print("    'stellar_mass': 'logmass',")
print("    'sfr': 'SFR_best',")
print("    'size': 're_arcsec',")
print("}")
# Out:
# MANUAL UPDATE REQUIRED:
# Please update the column_mapping dictionary above with the actual column names
# found in the previous cell output, then run the following cells.
#
# Example:
# column_mapping = {
#     'ra': 'RA_1',
#     'dec': 'DEC_1',
#     'redshift': 'z_phot',
#     'stellar_mass': 'logmass',
#     'sfr': 'SFR_best',
#     'size': 're_arcsec',
# }

# %%
 # Get valid redshift data
 REDSHIFT_COLUMN = 'redshift'
z_data = catalog[REDSHIFT_COLUMN]
valid_z = z_data[~np.isnan(z_data)]

print(f"Plotting {len(valid_z):,} objects with valid redshift data")
# Out:
# Plotting 0 objects with valid redshift data

# %%
  # Create histogram
  plt.hist(valid_z, bins=50, alpha=0.7, edgecolor='black',
  color='skyblue')
  plt.xlabel('Redshift')
  plt.ylabel('Number of galaxies')
  plt.title(f'Redshift Distribution 
  ({REDSHIFT_COLUMN})\n{len(valid_z):,} galaxies')

  # Add statistics
  median_z = np.median(valid_z)
  plt.axvline(median_z, color='red', linestyle='--',
  linewidth=2,
             label=f'Median: {median_z:.2f}')

  # Add Halpha observable range
  z_min_halpha = 0.48
  z_max_halpha = 7.0
  plt.axvspan(z_min_halpha, z_max_halpha, alpha=0.2,
  color='green',
             label=f'Hα observable 
  ({z_min_halpha}-{z_max_halpha})')

  plt.legend()
  plt.grid(True, alpha=0.3)
  plt.tight_layout()
  plt.show()

  # Print statistics
  print(f"\n=== REDSHIFT STATISTICS ===")
  print(f"Total objects: {len(z_data):,}")
  print(f"Valid redshifts: {len(valid_z):,} 
  ({len(valid_z)/len(z_data)*100:.1f}%)")
  print(f"Range: {valid_z.min():.3f} - {valid_z.max():.3f}")
  print(f"Median: {median_z:.3f}")
  print(f"Objects in Hα range: {np.sum((valid_z >= z_min_halpha)
   & (valid_z <= z_max_halpha)):,}")

# %%
# Apply initial selection criteria
# Only run this cell after updating column_mapping above!

def apply_initial_selection(cat, col_map):
    """
    Apply initial selection criteria to reduce catalog size
    """
    print("=== Applying Initial Selection Criteria ===")
    print(f"Starting with: {len(cat):,} objects")
    
    # Check if we have the required columns
    missing_cols = [k for k, v in col_map.items() if v is None or v not in cat.colnames]
    if missing_cols:
        print(f"ERROR: Missing required columns: {missing_cols}")
        print("Please update column_mapping in the previous cell")
        return cat
    
    # Create boolean mask for selection
    mask = np.ones(len(cat), dtype=bool)
    
    # 1. Valid redshift range for Halpha observability (0.48 < z < 7.0)
    z_col = col_map['redshift']
    z_min, z_max = 0.48, 7.0
    z_mask = (cat[z_col] > z_min) & (cat[z_col] < z_max) & np.isfinite(cat[z_col])
    mask &= z_mask
    print(f"After redshift cut ({z_min} < z < {z_max}): {mask.sum():,} objects")
    
    # 2. Valid stellar mass range (reasonable for galaxies)
    if col_map['stellar_mass'] in cat.colnames:
        mass_col = col_map['stellar_mass']
        mass_mask = (cat[mass_col] > 8.0) & (cat[mass_col] < 12.0) & np.isfinite(cat[mass_col])
        mask &= mass_mask
        print(f"After stellar mass cut (8 < log M* < 12): {mask.sum():,} objects")
    
    # 3. Valid SFR (remove non-detections/extreme values)
    if col_map['sfr'] in cat.colnames:
        sfr_col = col_map['sfr']
        sfr_mask = (cat[sfr_col] > 0) & (cat[sfr_col] < 1000) & np.isfinite(cat[sfr_col])
        mask &= sfr_mask
        print(f"After SFR cut (0 < SFR < 1000 M☉/yr): {mask.sum():,} objects")
    
    # 4. Valid coordinates
    ra_col, dec_col = col_map['ra'], col_map['dec']
    coord_mask = np.isfinite(cat[ra_col]) & np.isfinite(cat[dec_col])
    mask &= coord_mask
    print(f"After coordinate validity check: {mask.sum():,} objects")
    
    # Apply mask
    filtered_cat = cat[mask]
    print(f"\nFinal filtered catalog: {len(filtered_cat):,} objects")
    print(f"Reduction factor: {len(cat) / len(filtered_cat):.1f}x smaller")
    
    return filtered_cat

# Apply the selection (only if column_mapping is properly defined)
if all(v is not None for v in column_mapping.values()):
    filtered_catalog = apply_initial_selection(catalog, column_mapping)
else:
    print("Please update column_mapping first!")
# Out:
# === Applying Initial Selection Criteria ===
# Starting with: 784,016 objects
# After redshift cut (0.48 < z < 7.0): 0 objects
# After stellar mass cut (8 < log M* < 12): 0 objects
# After SFR cut (0 < SFR < 1000 M☉/yr): 0 objects
# After coordinate validity check: 0 objects
#
# Final filtered catalog: 0 objects
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[35], line 57
#      55 # Apply the selection (only if column_mapping is properly defined)
#      56 if all(v is not None for v in column_mapping.values()):
# ---> 57     filtered_catalog = apply_initial_selection(catalog, column_mapping)
#      58 else:
#      59     print("Please update column_mapping first!")
#
# Cell In[35], line 51, in apply_initial_selection(cat, col_map)
#      49 filtered_cat = cat[mask]
#      50 print(f"\nFinal filtered catalog: {len(filtered_cat):,} objects")
# ---> 51 print(f"Reduction factor: {len(cat) / len(filtered_cat):.1f}x smaller")
#      53 return filtered_cat
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## 6. Basic Visualizations of Filtered Sample

# %%
# Create basic plots if filtering was successful
if 'filtered_catalog' in locals() and len(filtered_catalog) > 0:
    # Convert to pandas for plotting
    plot_df = filtered_catalog.to_pandas()
    
    # Set up plotting
    plt.style.use('default')
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    axes = axes.flatten()
    
    # Get column names
    ra_col = column_mapping['ra']
    dec_col = column_mapping['dec']
    z_col = column_mapping['redshift']
    mass_col = column_mapping['stellar_mass']
    
    # 1. Sky distribution
    axes[0].scatter(plot_df[ra_col], plot_df[dec_col], s=0.5, alpha=0.5)
    axes[0].set_xlabel('RA (deg)')
    axes[0].set_ylabel('DEC (deg)')
    axes[0].set_title(f'Sky Distribution ({len(plot_df):,} objects)')
    
    # 2. Redshift distribution
    axes[1].hist(plot_df[z_col], bins=50, alpha=0.7, edgecolor='black')
    axes[1].set_xlabel('Redshift')
    axes[1].set_ylabel('Number of objects')
    axes[1].set_title('Redshift Distribution')
    axes[1].axvline(plot_df[z_col].median(), color='red', linestyle='--', 
                   label=f'Median: {plot_df[z_col].median():.2f}')
    axes[1].legend()
    
    # 3. Stellar mass distribution
    if mass_col in plot_df.columns:
        axes[2].hist(plot_df[mass_col], bins=50, alpha=0.7, edgecolor='black')
        axes[2].set_xlabel('log(M*/M☉)')
        axes[2].set_ylabel('Number of objects')
        axes[2].set_title('Stellar Mass Distribution')
        axes[2].axvline(plot_df[mass_col].median(), color='red', linestyle='--',
                       label=f'Median: {plot_df[mass_col].median():.2f}')
        axes[2].legend()
    
    # 4. Mass vs redshift
    if mass_col in plot_df.columns:
        axes[3].scatter(plot_df[z_col], plot_df[mass_col], s=0.5, alpha=0.3)
        axes[3].set_xlabel('Redshift')
        axes[3].set_ylabel('log(M*/M☉)')
        axes[3].set_title('Stellar Mass vs Redshift')
    
    plt.tight_layout()
    plt.show()
    
    print(f"\n=== Filtered Sample Statistics ===")
    print(f"Sample size: {len(plot_df):,} objects")
    print(f"Redshift range: {plot_df[z_col].min():.3f} - {plot_df[z_col].max():.3f}")
    if mass_col in plot_df.columns:
        print(f"Mass range: {plot_df[mass_col].min():.2f} - {plot_df[mass_col].max():.2f} dex")
else:
    print("No filtered catalog available for plotting. Please complete the previous steps.")

# %% [markdown]
# ## 7. Export Filtered Catalog

# %%
# Export the filtered catalog for further analysis
if 'filtered_catalog' in locals() and len(filtered_catalog) > 0:
    # Select only the columns we need to save space
    essential_cols = list(column_mapping.values())
    
    # Add any other useful columns (morphology, photometry, etc.)
    additional_cols = []
    for category, cols in found_cols.items():
        if category in ['morphology'] and cols:
            additional_cols.extend(cols[:3])  # Take first 3 morphology columns
    
    # Combine all columns we want to keep
    cols_to_keep = essential_cols + [col for col in additional_cols if col in filtered_catalog.colnames]
    cols_to_keep = list(set(cols_to_keep))  # Remove duplicates
    
    print(f"Exporting {len(cols_to_keep)} columns: {cols_to_keep}")
    
    # Create export dataframe
    export_df = filtered_catalog[cols_to_keep].to_pandas()
    
    # Rename columns to standard names
    rename_dict = {v: k for k, v in column_mapping.items() if v is not None}
    export_df = export_df.rename(columns=rename_dict)
    
    # Save to CSV
    output_file = '../data/processed/cosmos_web_filtered_catalog.csv'
    export_df.to_csv(output_file, index=False)
    
    print(f"\n=== Export Complete ===")
    print(f"Saved {len(export_df):,} objects to: {output_file}")
    print(f"File size: ~{len(export_df) * len(export_df.columns) * 8 / 1e6:.1f} MB")
    
    # Show sample of exported data
    print(f"\n=== Sample of Exported Data ===")
    print(export_df.head())
    
    # Create a summary file
    summary_file = '../data/processed/filtering_summary.txt'
    with open(summary_file, 'w') as f:
        f.write("COSMOSWeb Catalog Filtering Summary\n")
        f.write("=" * 40 + "\n\n")
        f.write(f"Original catalog size: {len(catalog):,} objects\n")
        f.write(f"Filtered catalog size: {len(export_df):,} objects\n")
        f.write(f"Reduction factor: {len(catalog) / len(export_df):.1f}x\n\n")
        f.write("Applied filters:\n")
        f.write("- Redshift: 0.48 < z < 7.0 (Halpha observable)\n")
        f.write("- Stellar mass: 8 < log(M*/M☉) < 12\n")
        f.write("- SFR: 0 < SFR < 1000 M☉/yr\n")
        f.write("- Valid coordinates\n\n")
        f.write(f"Column mapping used:\n")
        for k, v in column_mapping.items():
            f.write(f"- {k}: {v}\n")
    
    print(f"Summary saved to: {summary_file}")
    
else:
    print("No filtered catalog to export. Please complete the previous steps.")
